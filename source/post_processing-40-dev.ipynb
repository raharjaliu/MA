# %%
import os
import pathlib
import re
import copy
import warnings

from sys import getsizeof

import cv2
import xmltodict
import numpy as np
import pandas as pd
import tiffcapture as tc

from tifffile import imsave
from matplotlib import pyplot as pt

# %matplotlib inline

# %%
## for source implementation

# track_path = '../test/felix-bf-off/merged/out/tracked/'

# with open('../test/felix-bf-off/merged/out/tracked/merged_processed_brightness_corrected_Tracks.xml') as fd:
#     td = xmltodict.parse(fd.read())
    
# with open('../test/felix-bf-off/merged/out/tracked/merged_processed_brightness_corrected_save.xml') as fd:
#     sd = xmltodict.parse(fd.read())
    
# ss = pd.read_csv("../test/felix-bf-off/merged/out/tracked/All Spots statistics.csv")
# ts = pd.read_csv("../test/felix-bf-off/merged/out/tracked/Track statistics.csv")
# ba = pd.read_csv("../test/felix-bf-off/merged/out/tracked/Branch analysis.csv")

# %%
POSITION = 40
TIME_UNIT_FACTOR = 600
PIXEL_INCH_RATIO = .647
DIAMETER = 12

# %%
# path to exit data
exit_dat = '../results/40-47.csv'

# %%
track_path = '../test/eli-new-unsync-bf-%d/out-focus/merged/out/tracked/' % POSITION
with open(os.path.join(track_path, 'merged_Tracks.xml')) as fd:
    td = xmltodict.parse(fd.read())
    
with open(os.path.join(track_path, 'merged.xml')) as fd:
    sd = xmltodict.parse(fd.read())
    
ss = pd.read_csv(os.path.join(track_path, 'All Spots statistics.csv'))
ts = pd.read_csv(os.path.join(track_path, 'Track statistics.csv'))
ba = pd.read_csv(os.path.join(track_path, 'Links in tracks statistics.csv'))
sits = pd.read_csv(os.path.join(track_path, 'Spots in tracks statistics.csv'))

## TODO: include the last one file (branch statistics)

# %%
caspase_path = "../test/eli-new-unsync-bf-%d/caspase/" % POSITION
caspase_tiff_path = os.path.join(caspase_path, "caspasexy%dc1_sub.tif" % POSITION)
# tiff_path_intersection = os.path.join(caspase_path, "caspasexy%dc1_inter.tif" % POSITION)

out_path_pics = "../results/pics/unsyn/"
if not os.path.exists(out_path_pics):
    os.makedirs(out_path_pics)

# %% [markdown]
# #  Function Defs and Uses
#
# ### Reference-safe key removal

# %%
def removekey(d, key):
    """
    Remove a key from a  dictionary without destroying the reference
    to removed object (which might be used by other processes)
    """
    if key in d:
        r = dict(d)
        del r[key]
        return r

# %% [markdown]
# ### Reconstruct tree from "Links in Track Statistics" file

# %%
def parse_trees(links_tab):
    """
    Given 'links in tab statistics' from TrackMate.
    Construct data structures representing trees ('tree') and
    their branching ('branch') respectively.
    
    -   'tree' contains mapping of TREE_ID (which is the same as
        the id of root's SPOT_ID) to its associated tree.
        Each tree is in turn a map of TREE_BRANCH_ID
        (which is the branch's first spot's SPOT_ID)
        to its branch which is represented as list of SPOT_ID's.
    -   'branch' encodes how the tree is structured. It contains
        mapping of TREE_ID to the branching configuration.
        The branching configuration is encoded as mapping of
        BRANCH_ID to its two children's BRANCH_ID.
    """
    
    tree = {}
    branch = {}
    for track in links_tab.TRACK_ID.unique():
    
        sub = links_tab[links_tab.TRACK_ID == track]

        this_lines = {}
        this_branches = {}
        stack = []
    
        groot = sub.iloc[0][3] 
        print("Parsing tree %s" % groot)
        stack.append(groot)
    
        while len(stack) > 0:
        
            root = stack.pop()
            track = [root]
            print("Parsing subtree %s" % root)
            nsub = sub[sub.SPOT_SOURCE_ID == root]
        
            while nsub.index.size > 0:
                if nsub.index.size == 1:
                    this = nsub.iloc[0][4]
                    track.append(this)
                    nsub = sub[sub.SPOT_SOURCE_ID == this]
                else:
                    stack.append(nsub.iloc[0][4])
                    stack.append(nsub.iloc[1][4])
                    this_branches[root] = (nsub.iloc[0][4], nsub.iloc[1][4])
                    print("breaking")
                    break
                
            this_lines[root] = track
            print("adding branch %s" % root)
    
        print("Finishing...")
        tree[groot] = this_lines
        branch[groot] = this_branches
        
    return tree, branch

# %% [markdown]
# ### Extract values measured by TrackMate

# %%
def extract_values(tree, spots_tab, colnames):
    """
    Extract varoius measurement values from spots statistics and save it
    in format similar to parsed tree. The list of values to be extracted
    from spots statistics is defined in 'colnames' 
    
    The information will be stored in following format:
    map(TYPE:(TREE_ID:TREE_BRANCH:list(VALUES))
    
    """
    
    vals = {}

    for tr in tree:
    
        print("extracting values for %s" % tr)
    
        for colname in colnames:
        
            val_tree = {}
        
            for br in tree[tr]:
            
                brkeys = tree[tr][br]
                brvals = [sits[sits.ID == x][colname].values[0] for x in brkeys]
            
                val_tree[br] = brvals
            
            if colname not in vals:
                vals[colname] = {}
            
            vals[colname][tr] = val_tree
            
    return vals

# %% [markdown]
# ### Plot tree values for a given tree

# %%
def plot_tree_value(tree_id, value, tree_values):
    """
    Plot a given value of a given tree over the time
    """
    
    for key in tree_values['POSITION_T'][tree_id]:
    
        pt.plot(tree_values['POSITION_T'][tree_id][key], 
                svals['TOTAL_INTENSITY'][tree_id][key], 
                label="%d" % key)
    
    pt.title("%s of tree %d over time" % (value, tree_id))
    pt.xlabel("Time")
    pt.ylabel("%s" % value)
    frame = pt.gcf()
    frame.set_size_inches(20, 10)

# %% [markdown]
# ### Recognize slits in contour mask picture (simplified)

# %%
def recognize_slits(img, minsize=6000, maxsize=float("inf")):
    """
    Reads contour mask picture and recognizes slits.
    Slit is defined as having size between $minsize and $maxsize
    This is a simplified version of get_contour
    """
    gray= cv2.cvtColor(img,
                       cv2.COLOR_BGR2GRAY)
    im2, contours, hierarchy  = cv2.findContours(gray, 
                                                 cv2.RETR_LIST,
                                                 cv2.CHAIN_APPROX_SIMPLE)
    
    cts = [ct for ct in contours if (cv2.contourArea(ct) > minsize and cv2.contourArea(ct) < maxsize)]
    return cts

# %% [markdown]
# ### Extract slits, their corresponding area and the area of all contours (slits or not)

# %%
def get_contour(contour_mask_path, min_size=7000, max_size=10000):
    """
    Give contour mask picture (created by adjusting contrast/brightness
    followed by RATS and "fill holes" command) detect contours of
    slits annd return:
    - the list of filtered contours
    - the size list of filtered contours
    - the size of all detected contours (for testing purpose)
    """
    
    ## collect contours and wrap into a function

    im = cv2.imread(contour_mask_path)
    gray= cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    im2, contours, hierarchy  = cv2.findContours(gray,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)

    all_cts_area = np.array([cv2.contourArea(x) for x  in contours])

    filtered_cts = []
    filtered_cts_area = []

    for ct in contours:
        ct_area = cv2.contourArea(ct)
        if (ct_area <= max_size) and (ct_area >= min_size):
            filtered_cts.append(ct)
            filtered_cts_area.append(ct_area)
            
    return filtered_cts, filtered_cts_area, all_cts_area

# %% [markdown]
# ###  Assign cell tree to a contour

# %%
def assign_tree_to_contours(tree_values, contours):
    """
    Given tree values and recognized contours, compute:
    
    -   'assocs': table listing recognized slit and the TREE_ID
        of singly-placed cell tree located in the slit
    -   'occupancy': list containing the number of cell trees
        located in a slit. NOTE: the list is not associated with
        ordering encoded in 'assocs'
    """

    occuppancy = {x:0 for x in range(len(contours))}
    cell_trees = []
    slits = []

    for tr in tree_values['POSITION_X'].keys():
    
        cell_trees.append(tr)

        x = tree_values['POSITION_X'][tr][tr][0] / PIXEL_INCH_RATIO
        y = tree_values['POSITION_Y'][tr][tr][0] / PIXEL_INCH_RATIO
    
        counter = 0
        match = 0
        matchloc = None
    
        for ct in cts:
        
            if cv2.pointPolygonTest(ct, (x, y), False) > 0:
                occuppancy[counter] += 1
                matchloc = counter
                match += 1
            counter +=  1
        
        if match == 0:
            slits.append(None)
        elif match == 1:
            slits.append(matchloc)
        else:
            print("Tree %s got too many matches" % tr)
        
    assocs = pd.DataFrame({'CELL_LINE': cell_trees, 'SLIT_ID': slits})
    occuppancy = np.array(list(occuppancy.values()))
    
    return assocs, occuppancy

# %% [markdown]
# ### Filter out trees laying outside the allowed time range

# %%
def filter_trees_by_time(tree, branch, tree_values, min_time=0, max_time=10):
    """
    Filter out trees which measurement time start before or after
    the time as defined in 'min_time' and 'max_time'.
    
    Measurement time is defined as the return value from TrackMate
    encoded as 'POSITION_T'
    """
    
    tree_values_filtered = {}
    tree = copy.deepcopy(tree)
    branch = copy.deepcopy(branch)

    for v in tree_values.keys():
        tree_values_filtered[v] = {}

    for key in tree_values['POSITION_T'].keys():
    
        if (tree_values['POSITION_T'][key][key][0] >= min_time) and (tree_values['POSITION_T'][key][key][0] <= max_time):
            for k in tree_values_filtered.keys():
                tree_values_filtered[k][key] = tree_values[k][key]
        else:
            tree = removekey(tree, key)
            branch = removekey(branch, key)
                
    return  tree, branch, tree_values_filtered

# %% [markdown]
# ### Computer tree's first division time

# %%
def compute_first_division_time(tree_id, tree, branch, tree_measurements, mode=['avg', 'min', 'max']):
    """
    Compute the first division time of a tree. The first division time
    could be computed with following mode:
    
    -   'avg': averaging time difference between the last measurement
        time of main branch and first measurement time of each 
        child branches
    -   'min': taking the minimum of both values
    -   'max': taking the maximum of both values
    """    
    
    t_time = tree_measurements['POSITION_T'][tree_id]
    t_tree = tree[tree_id]
    t_branch = branch[tree_id]
    
    div_end_main = t_time[tree_id][-1]
    div_start_1 = t_time[t_branch[tree_id][0]][0]
    div_start_2 = t_time[t_branch[tree_id][1]][0]
    
    if mode == 'avg':
        return div_end_main + float(div_start_1 + div_start_2 - 2 * div_end_main) / 4
    elif mode == 'min':
        return div_end_main + min((div_start_2 - div_end_main) / 2, (div_start_2 - div_end_main) / 2)
    elif mode == 'max':
        return div_end_main + max((div_start_2 - div_end_main) / 2, (div_start_2 - div_end_main) / 2)
    elif mode == ['avg', 'min', 'max']:
        # default mode, compute avg
        return div_end_main + float(div_start_1 + div_start_2 - 2 * div_end_main) / 4
    else:
        raise("Wrong mode. Mode has to be either 'avg', 'max' or 'min")
        

def compute_first_division_time_list(tree_ids, tree, branch, tree_measurements, mode=['avg', 'min', 'max']):
    """
    Wrapper function of compute_first_division_time().
    This function takes list of TREE_IDs and compute 
    the first division time for each tree.
    """

    div_times = []

    for t in tree_ids:
        div_times.append(compute_first_division_time(t, tree, branch, tree_measurements, mode=mode))
    
#         print("t1, t2, t3: %d, %d, %d" % (div_end_main, div_start_1, div_start_2))
#         print("t_div: %f" % div_time)
    
    return div_times

# %% [markdown]
# ### Get trees by placement

# %%
def get_trees_by_placement(tree_assoc, placement=1):
    """
    Get all cell trees that have the same placement as described in argument.
    A cell tree is of placement n if it is located in a slit with (n - 1)
    other cell trees. 'placement' is by definition larger than 0
    """
    if placement < 1:
        print("'placement' has to be at least 1")
        return []
    else:
        trees = []
        for slit in tree_assoc.SLIT_ID.unique():
            if tree_assoc[tree_assoc.SLIT_ID == slit].index.size == placement:
                trees.append(tree_assoc[tree_assoc.SLIT_ID == slit]['CELL_LINE'].values[0])
    
        return trees

# %%
## EMPTY SPACE FOR FILTERING STEP
## TODO: wrap routine as function

# %% [markdown]
# ## Construct left-depth-first queue for a given (sub)tree

# %%
def construct_queue(br, q, cur):
    """
    Given branching configuration of a tree,
    construct queue representation (DFS) of such tree
    """
    
    if cur not in br:
        q.append(cur)
        return q
    else:
        q.append(cur)
        q = construct_queue(br, q, br[cur][0])
        q = construct_queue(br, q, br[cur][1])
        return q

# %% [markdown]
# ### Create and write video time-lapse for given tree in its associated slit

# %%
def export_snapshot(tree_ids, tree_assoc, slit_contours, tree, branch, tree_values, tiff_path, out_path):
    """
    Create video containing trees, whic are STRICTLY assumed to be in one slit,
    and write the video (as TIFF) on given path.
    
    Each spot in the tree will be annotated with green dot. The slit, which
    trees reside in, will be highlighted in red line.
    
    Since the video only contains the slit in which the first tree resides in,
    only trees located in the same slit as the first tree will be shown in the video.
    """
    
    ### ALL tree_ids HAVE TO OCCUPY THE SAME SLIT
    
    print("Exporting snapshot for trees: %s" % str(tree_ids))
    
    ### STEP I: parse TIFF template
    
    t_slit_id = int(tree_assoc[tree_assoc.CELL_LINE == tree_ids[0]].SLIT_ID.values[0])
    t_slit = slit_contours[t_slit_id]
    
    ## import tiff images
    tifmask = tc.opentiff(tiff_path)

    ## first image
    _, first_img = tifmask.retrieve()
    first_img = cv2.cvtColor(first_img,cv2.COLOR_GRAY2RGB)
    cv2.drawContours(first_img, [t_slit], -1, (255, 0, 0), 4)

    ## bounding box for slices
    bb = cv2.boundingRect(t_slit)
    bb = (bb[0], bb[1], bb[0] + bb[2], bb[1] + bb[3])
    # extend bounding box by 10 pixels to all directions if possible
    bb = (max(0, bb[0] - 10), 
          max(0, bb[1] - 10), 
          min(first_img.shape[0], bb[2] + 10),
          min(first_img.shape[1], bb[3] + 10))

    # assign bounding box for first image
    cv2.rectangle(first_img, (bb[0], bb[1]), (bb[2], bb[3]), (0, 0, 255))

    ## slices
    pics = [first_img]

    for slide in tifmask:
        # convert grayscale to RGB
        slide = cv2.cvtColor(slide, cv2.COLOR_GRAY2RGB)
        # draw contour of slit
        cv2.drawContours(slide, [t_slit], -1, (255, 0, 0), 4)
        cv2.rectangle(slide, (bb[0], bb[1]), (bb[2], bb[3]), (0, 0, 255))
        pics.append(slide)
    
    # free memory
    tifmask.release()
    
    ### STEP II: assign track onto template
    
    for tree_id in tree_ids:
        
        print("Exporting snapshot for tree %d..." % tree_id)
    
        t_slit_id = int(tree_assoc[tree_assoc.CELL_LINE == tree_id].SLIT_ID.values[0])
        t_slit = slit_contours[t_slit_id]
        t_tree = tree[tree_id]
        t_branch = branch[tree_id]
        t_time = tree_values['POSITION_T'][tree_id]
        t_x = tree_values['POSITION_X'][tree_id]
        t_y = tree_values['POSITION_Y'][tree_id]

        ## extract spatial info and embed into image
        t_queue = construct_queue(t_branch, [], tree_id)
    
        print("branch configuration for tree %d:\n%s" % (tree_id, str(t_branch)))
        print("parsed queue for tree %d: %s" % (tree_id, str(t_queue)))
    
        for br in t_queue:
            t_tree_br = t_tree[br]
    
            # mark identified dots on corresponding slide
            for i in range(len(t_tree_br)):
                this_t = int(t_time[br][i] / TIME_UNIT_FACTOR)
                this_x = t_x[br][i] / PIXEL_INCH_RATIO
                this_y = t_y[br][i] / PIXEL_INCH_RATIO
                img = pics[this_t]
        
                cv2.circle(img, (int(this_x), int(this_y)), 4, (0, 255, 0), -1)

    ## crop images
    pics_cropped = []
    for i in range(len(pics)):
        this_pic_cropped = pics[i][bb[1]:bb[3], bb[0]:bb[2]]
        pics_cropped.append(this_pic_cropped)

    ## write vid
    if not os.path.exists(out_path):
        os.makedirs(out_path)
    print("writting video to dir: %s" % out_path) 
    
    ## save to multipages tiff
    imsave(os.path.join(out_path, '%d.tiff' % t), np.array(pics_cropped))
    
    ## release memory
    pics = []
    pics_cropped = []
    
    print("#Trees snapshot exported")
    
    
def export_snapshot_slit(slit_id, tree_assoc, slit_contours, tree, branch, tree_values, tiff_path, out_path):
    """
    Wrapper function for 'export_snapshot()'. In this function a user is only
    required to give the ID of slit of interest. 'export_snapshot()' will then
    be callld with trees residing in the passed slit.
    """
    print("Exporting snapshot for slit %d" % slit_id)
    tree_ids = tree_assoc[tree_assoc.SLIT_ID == slit_id]['CELL_LINE'].tolist()
    export_snapshot(tree_ids, 
                    tree_assoc, 
                    slit_contours, 
                    tree, 
                    branch, 
                    tree_values, 
                    tiff_path, 
                    out_path)

# %% [markdown]
# ### Read TIFF into list of frames (represented as multidim array)

# %%
def get_video(path, to_rgb=False):
    """
    Read TIFF file containing multiple stacks (a video)
    and return sequential array of frame encoded as
    multidimensional array
    """
    
    tif = tc.opentiff(path)
    
    ## first image
    _, first_img = tif.retrieve()
    if to_rgb:
        first_img = cv2.cvtColor(first_img,cv2.COLOR_GRAY2RGB)

    ## slices
    pics = [first_img]

    for slide in tif:
        # convert grayscale to RGB
        if to_rgb:
            slide = cv2.cvtColor(slide, cv2.COLOR_GRAY2RGB)
        pics.append(slide)
    
    return pics

# %% [markdown]
# ### Extract (procedded) cell death signal video's brightness level for each spot

# %%
def extract_brightness(tree_id, tree, tree_values, reference_vid_path, diameter=12):
    """
    Given cell death signal video, extract brightness level for each position
    of tracked cell trees, if such poisition coincides with the.
    
    This function returns:
    -   the brightness level of each spot in the tree, if such is measured.
        The encoding follows that of the tree itself
    -   cell death signal time-lapsed video of containing the cell belonging
        to the 'tree_id'. Useful for debugging/sanity testing 
    """
    
    pics = get_video(reference_vid_path)
    pics_intersect = []

    t_time = tree_values['POSITION_T'][tree_id] # tree_values
    t_x = tree_values['POSITION_X'][tree_id]
    t_y = tree_values['POSITION_Y'][tree_id]
    t_tree = tree[tree_id]

    t_brightness = {}

    for br in t_tree:
        brch = t_tree[br]
        x = t_x[br]
        y = t_y[br]
        time = t_time[br]
        brightness = []
    
        for i in range(len(brch)):
            if ((time[i] - 76200) >= 0) & ((time[i] - 76200) % 1800 == 0):
                pos = (time[i] - 76200) // 1800
                pic_base = pics[pos]
                pic_bg = np.zeros(pic_base.shape, np.uint16)
                pic_bg = cv2.circle(pic_bg, 
                                   (int(x[i] / PIXEL_INCH_RATIO), int(y[i] / PIXEL_INCH_RATIO)),
                                   int(diameter / PIXEL_INCH_RATIO),
                                   (255, 255, 255),
                                   -1)
                pic = cv2.bitwise_and(pic_base, pic_bg)
                brightness.append(cv2.sumElems(pic)[0])
                pics_intersect.append(pic)
            else:
                brightness.append(np.nan)
            
        t_brightness[br] = brightness
    return t_brightness, np.array(pics_intersect)

# %% [markdown]
# ### Visualize Cell Death Signal Data

# %%
def visualize_brightness_data(tree_id, tree, tree_values, reference_vid_path, diameter=12, save_vid=False, 
                              vid_path=None, out_path=None):
    """
    This methods plots the progression of a the brightness coming from
    processed cell death signal channel over time, which directly
    corresponds to the strength of cell death signal.
    
    The method also offers the possibility to save a modified version of
    time-lapsed video of cell death signal in which it only shows 
    the cells belonging to the tree of interest (as defined in 'tree_id')
    
    This method is somewhat related to 'extract_brightness()'. However,
    this returns no value and only plots the results and saves
    the modified video (if 'save_vid' is True).
    """
    
    print("visualizing tree %d" % tree_id)

    t_time = tree_values['POSITION_T'][tree_id]
    t_x = tree_values['POSITION_X'][tree_id]
    t_y = tree_values['POSITION_Y'][tree_id]
    t_tree = tree[tree_id]
    
    if save_vid:
        t_brightness, video = extract_brightness(tree_id, tree, tree_values, vid_path)
    else:
        t_brightness, _ = extract_brightness(tree_id, tree, tree_values, vid_path)
    
    for br in t_brightness:
        brightness = np.array(t_brightness[br])
        time = np.array(t_time[br])
        time = time[~np.isnan(brightness)]
        brightness= brightness[~np.isnan(brightness)]
        pt.plot(time, brightness, label="%d" % br)

    pt.legend(loc='best')
    pt.title("Cell line %d brightness measurement over time" % tree_id)
    pt.ylabel("Sum of cell's pixels' brightness (8-bit encoding)")
    pt.xlabel("Time (s)")
    pt.savefig(os.path.join(out_path_pics, "%d-%d.pdf" % (POSITION, tree_id)))
    pt.clf()
    
    print("  plot written to %s" % (os.path.join(out_path_pics, "%d-%d.pdf" % (POSITION, tree_id))))
    
    if save_vid:
        imsave(os.path.join(out_path, 'test-%d.tiff' % tree_id), np.array(video))
        print("  video written to %s" % os.path.join(out_path, 'test-%d.tiff' % tree_id))
        video = []

# %% [markdown]
# ### Incorporate cell death information into cell trees

# %%
def embed_cell_death_signal(tree_id, 
                            tree, 
                            branch, 
                            tree_values, 
                            reference_vid_path, 
                            lookup_window=6,
                            cell_death_value=3000):
    """
    Incorporate cell death information coming from cell death signal channel
    into the data. A cell is defined as death if:
    
        For at least twice within $lookup_window franes of out-focus
        video the corresponding values of cell death signal are above
        $cell_death_value
        
    Upon cell death determination, two things are done:
    -   removal of all successors of the dead cell all the way to
        the leaves.
    -   update of measurement data of dead cell. All measurements
        beyond the time of death are removed from the data.
        
    NOTE THAT the operation is done on deep-copied objects and hence
    the original objects wouldn't be affected at all
    """
    
    print("processing tree %d" % tree_id)

    t_tree = tree[tree_id]
    t_branch = branch[tree_id]
    t_brightness, _ = extract_brightness(tree_id, tree, tree_values, reference_vid_path)
    tree_values = copy.deepcopy(tree_values)
    
    # use cloned objects to not affect original objects
    t_tree = copy.deepcopy(t_tree)
    t_branch = copy.deepcopy(t_branch)

    t_queue = construct_queue(t_branch, [], tree_id)

    while len(t_queue) > 0:
        
        q = t_queue.pop(0)
        print("  processing branch %d" % q)
        
        brch = t_tree[q]
        bghtns = t_brightness[q]
    
        death = None
    
        # find repeated signal brightness values > $cell_death_value
        for i in range(len(bghtns)):
            if (bghtns[i] > cell_death_value) and (i < len(bghtns) - lookup_window):
            
                # forward lookup for repeated death signal
                for j in range(i + 1, min(len(bghtns), i + lookup_window + 1)):
                    if bghtns[j] > cell_death_value:
                        death = i
                        break
                
                if death is not None:
                    print("    branch %d marked dead" % q)
                
                    """
                    change:
                    - tree
                    - branch
                    - tree_values (x, y, etc)
                    """
                    
                    # delete branch and its kids
                    to_modify = construct_queue(t_branch, [], q)
                    
                    for tm in to_modify[1:]:
                        # delete each kid of dead branch (quite unlikely but just incase)
                        print("      removing {tree, brightness, measurement values} of  %d from tree" % tm)
                        t_tree = removekey(t_tree, tm)
                        t_brightness = removekey(t_brightness, tm)
                        if q in t_branch:
                            t_branch = removekey(t_branch, q)
                        for key in tree_values:
                            tree_values[key][tree_id] = removekey(tree_values[key][tree_id], tm)
                        t_queue.remove(tm)
                
                    # delete tailing measurements from branch and removing kids from branching conf
                    print("    shortening {tree, brightness, measurement values} of %d at position %d (exclusive)" % (q, death))
                    t_tree[q] = t_tree[q][:i+1]
                    t_brightness[q] = t_brightness[q][:i+1]
                    if q in t_branch:
                        t_branch = removekey(t_branch, q)
                        
                    for key in tree_values:
                        tree_values[key][tree_id][q] = tree_values[key][tree_id][q][:i+1]
                    break
                
    return t_tree, t_branch, t_brightness, tree_values

# %% [markdown]
# ### Write out time-to-death statistics

# %%
def write_time_to_death_statistics(stats_path, tree_ids, div_times, ttd1s, ttd2s, append=True):
    """
    Write out the computer time-to-death statistics
    into the file given by 'stats_path'
    """

    out = list(zip(*[[POSITION] * len(tree_ids), tree_ids, div_times, ttd1s, ttd2s]))
    out = [list(i) for i in out]
    outstr = []

    for i in range(len(out)):
        outstr.append([str(j) for j in out[i]])
    
    resstr = ""

    for i in range(len(outstr)):
        resstr += (",".join(outstr[i]) + "\n")
    
    if append:
        with open(stats_path, "a") as myfile:
            myfile.write(resstr)
    else:
        with open(stats_path, "w") as myfile:
            myfile.write(resstr)

# %% [markdown]
# ### Delete all declared variables in notebook

# %%
def delete_all_variables():
    
    # %reset

# %% [markdown]
# # Pipeline

# %% [markdown]
# ### I. Parsing TrackMate Output

# %%
for track in ba.TRACK_ID.unique():
    sub = ba[ba.TRACK_ID == track]
    pt.plot(range(sub.index.size), sub.EDGE_TIME - sub.EDGE_TIME.min())
    
frm = pt.gcf()
frm.set_size_inches(16, 10)

# %%
tree, branch = parse_trees(ba)
# Out:
# Parsing tree 29292
# Parsing subtree 29292
# breaking
# adding branch 29292
# Parsing subtree 396233
# adding branch 396233
# Parsing subtree 396191
# breaking
# adding branch 396191
# Parsing subtree 549111
# adding branch 549111
# Parsing subtree 549139
# breaking
# adding branch 549139
# Parsing subtree 901924
# adding branch 901924
# Parsing subtree 901883
# adding branch 901883
# Finishing...
# Parsing tree 29303
# Parsing subtree 29303
# breaking
# adding branch 29303
# Parsing subtree 138144
# adding branch 138144
# Parsing subtree 138143
# adding branch 138143
# Finishing...
# Parsing tree 33558
# Parsing subtree 33558
# breaking
# adding branch 33558
# Parsing subtree 435064
# adding branch 435064
# Parsing subtree 435026
# adding branch 435026
# Finishing...
# Parsing tree 33793
# Parsing subtree 33793
# breaking
# adding branch 33793
# Parsing subtree 176502
# breaking
# adding branch 176502
# Parsing subtree 535614
# breaking
# adding branch 535614
# Parsing subtree 571305
# adding branch 571305
# Parsing subtree 571286
# breaking
# adding branch 571286
# Parsing subtree 612627
# breaking
# adding branch 612627
# Parsing subtree 746175
# breaking
# adding branch 746175
# Parsing subtree 763558
# adding branch 763558
# Parsing subtree 763573
# breaking
# adding branch 763573
# Parsing subtree 1105735
# adding branch 1105735
# Parsing subtree 1105791
# adding branch 1105791
# Parsing subtree 746190
# adding branch 746190
# Parsing subtree 612626
# adding branch 612626
# Parsing subtree 535651
# adding branch 535651
# Parsing subtree 176508
# adding branch 176508
# Finishing...
# Parsing tree 30821
# Parsing subtree 30821
# adding branch 30821
# Finishing...
# Parsing tree 30564
# Parsing subtree 30564
# adding branch 30564
# Finishing...
# Parsing tree 33263
# Parsing subtree 33263
# breaking
# adding branch 33263
# Parsing subtree 481819
# adding branch 481819
# Parsing subtree 481808
# adding branch 481808
# Finishing...
# Parsing tree 30583
# Parsing subtree 30583
# adding branch 30583
# Finishing...
# Parsing tree 29335
# Parsing subtree 29335
# adding branch 29335
# Finishing...
# Parsing tree 29593
# Parsing subtree 29593
# breaking
# adding branch 29593
# Parsing subtree 195339
# adding branch 195339
# Parsing subtree 195338
# adding branch 195338
# Finishing...
# Parsing tree 30822
# Parsing subtree 30822
# breaking
# adding branch 30822
# Parsing subtree 743661
# adding branch 743661
# Parsing subtree 743697
# breaking
# adding branch 743697
# Parsing subtree 1039181
# adding branch 1039181
# Parsing subtree 1039211
# adding branch 1039211
# Finishing...
# Parsing tree 34833
# Parsing subtree 34833
# adding branch 34833
# Finishing...
# Parsing tree 31322
# Parsing subtree 31322
# breaking
# adding branch 31322
# Parsing subtree 450366
# adding branch 450366
# Parsing subtree 450310
# adding branch 450310
# Finishing...
# Parsing tree 32020
# Parsing subtree 32020
# breaking
# adding branch 32020
# Parsing subtree 761779
# adding branch 761779
# Parsing subtree 761728
# adding branch 761728
# Finishing...
# Parsing tree 34110
# Parsing subtree 34110
# adding branch 34110
# Finishing...
# Parsing tree 33603
# Parsing subtree 33603
# breaking
# adding branch 33603
# Parsing subtree 724939
# adding branch 724939
# Parsing subtree 724917
# adding branch 724917
# Finishing...
# Parsing tree 32478
# Parsing subtree 32478
# breaking
# adding branch 32478
# Parsing subtree 688180
# adding branch 688180
# Parsing subtree 688194
# breaking
# adding branch 688194
# Parsing subtree 755314
# adding branch 755314
# Parsing subtree 755315
# adding branch 755315
# Finishing...
# Parsing tree 32067
# Parsing subtree 32067
# breaking
# adding branch 32067
# Parsing subtree 474973
# breaking
# adding branch 474973
# Parsing subtree 723446
# breaking
# adding branch 723446
# Parsing subtree 925329
# adding branch 925329
# Parsing subtree 925346
# adding branch 925346
# Parsing subtree 723445
# adding branch 723445
# Parsing subtree 474919
# adding branch 474919
# Finishing...
# Parsing tree 30076
# Parsing subtree 30076
# adding branch 30076
# Finishing...
# Parsing tree 29360
# Parsing subtree 29360
# adding branch 29360
# Finishing...
# Parsing tree 29935
# Parsing subtree 29935
# breaking
# adding branch 29935
# Parsing subtree 23695
# adding branch 23695
# Parsing subtree 23604
# adding branch 23604
# Finishing...
# Parsing tree 27192
# Parsing subtree 27192
# adding branch 27192
# Finishing...
# Parsing tree 33604
# Parsing subtree 33604
# breaking
# adding branch 33604
# Parsing subtree 1314413
# adding branch 1314413
# Parsing subtree 1314350
# breaking
# adding branch 1314350
# Parsing subtree 1376391
# breaking
# adding branch 1376391
# Parsing subtree 1447261
# adding branch 1447261
# Parsing subtree 1447338
# adding branch 1447338
# Parsing subtree 1376436
# adding branch 1376436
# Finishing...
# Parsing tree 29597
# Parsing subtree 29597
# adding branch 29597
# Finishing...
# Parsing tree 34379
# Parsing subtree 34379
# adding branch 34379
# Finishing...
# Parsing tree 32772
# Parsing subtree 32772
# breaking
# adding branch 32772
# Parsing subtree 79303
# adding branch 79303
# Parsing subtree 79258
# breaking
# adding branch 79258
# Parsing subtree 440222
# adding branch 440222
# Parsing subtree 440260
# adding branch 440260
# Finishing...
# Parsing tree 33294
# Parsing subtree 33294
# breaking
# adding branch 33294
# Parsing subtree 130592
# adding branch 130592
# Parsing subtree 130618
# breaking
# adding branch 130618
# Parsing subtree 136201
# adding branch 136201
# Parsing subtree 136210
# breaking
# adding branch 136210
# Parsing subtree 273081
# breaking
# adding branch 273081
# Parsing subtree 336394
# adding branch 336394
# Parsing subtree 336395
# breaking
# adding branch 336395
# Parsing subtree 470358
# adding branch 470358
# Parsing subtree 470369
# breaking
# adding branch 470369
# Parsing subtree 564998
# breaking
# adding branch 564998
# Parsing subtree 776497
# adding branch 776497
# Parsing subtree 776470
# breaking
# adding branch 776470
# Parsing subtree 1048846
# adding branch 1048846
# Parsing subtree 1048791
# adding branch 1048791
# Parsing subtree 565036
# adding branch 565036
# Parsing subtree 273075
# adding branch 273075
# Finishing...
# Parsing tree 29108
# Parsing subtree 29108
# breaking
# adding branch 29108
# Parsing subtree 472158
# adding branch 472158
# Parsing subtree 472185
# adding branch 472185
# Finishing...
# Parsing tree 32546
# Parsing subtree 32546
# adding branch 32546
# Finishing...
# Parsing tree 33641
# Parsing subtree 33641
# adding branch 33641
# Finishing...
# Parsing tree 33910
# Parsing subtree 33910
# breaking
# adding branch 33910
# Parsing subtree 238873
# adding branch 238873
# Parsing subtree 238867
# breaking
# adding branch 238867
# Parsing subtree 482388
# adding branch 482388
# Parsing subtree 482389
# adding branch 482389
# Finishing...
# Parsing tree 29385
# Parsing subtree 29385
# breaking
# adding branch 29385
# Parsing subtree 234495
# adding branch 234495
# Parsing subtree 234541
# adding branch 234541
# Finishing...
# Parsing tree 29093
# Parsing subtree 29093
# adding branch 29093
# Finishing...
# Parsing tree 30422
# Parsing subtree 30422
# breaking
# adding branch 30422
# Parsing subtree 362182
# adding branch 362182
# Parsing subtree 362196
# breaking
# adding branch 362196
# Parsing subtree 520410
# breaking
# adding branch 520410
# Parsing subtree 875644
# adding branch 875644
# Parsing subtree 875607
# adding branch 875607
# Parsing subtree 520448
# adding branch 520448
# Finishing...
# Parsing tree 30857
# Parsing subtree 30857
# breaking
# adding branch 30857
# Parsing subtree 111089
# adding branch 111089
# Parsing subtree 111090
# breaking
# adding branch 111090
# Parsing subtree 190852
# adding branch 190852
# Parsing subtree 190879
# adding branch 190879
# Finishing...
# Parsing tree 16750
# Parsing subtree 16750
# adding branch 16750
# Finishing...
# Parsing tree 30865
# Parsing subtree 30865
# adding branch 30865
# Finishing...
# Parsing tree 32127
# Parsing subtree 32127
# breaking
# adding branch 32127
# Parsing subtree 364037
# breaking
# adding branch 364037
# Parsing subtree 593647
# breaking
# adding branch 593647
# Parsing subtree 646623
# adding branch 646623
# Parsing subtree 646650
# adding branch 646650
# Parsing subtree 593589
# adding branch 593589
# Parsing subtree 364063
# adding branch 364063
# Finishing...
# Parsing tree 33909
# Parsing subtree 33909
# adding branch 33909
# Finishing...
# Parsing tree 29139
# Parsing subtree 29139
# breaking
# adding branch 29139
# Parsing subtree 58795
# adding branch 58795
# Parsing subtree 58748
# adding branch 58748
# Finishing...
# Parsing tree 31384
# Parsing subtree 31384
# adding branch 31384
# Finishing...
# Parsing tree 32107
# Parsing subtree 32107
# adding branch 32107
# Finishing...
# Parsing tree 33673
# Parsing subtree 33673
# breaking
# adding branch 33673
# Parsing subtree 701086
# breaking
# adding branch 701086
# Parsing subtree 1062940
# adding branch 1062940
# Parsing subtree 1062913
# breaking
# adding branch 1062913
# Parsing subtree 1230320
# adding branch 1230320
# Parsing subtree 1230352
# breaking
# adding branch 1230352
# Parsing subtree 1283683
# adding branch 1283683
# Parsing subtree 1283644
# adding branch 1283644
# Parsing subtree 701095
# adding branch 701095
# Finishing...
# Parsing tree 31892
# Parsing subtree 31892
# breaking
# adding branch 31892
# Parsing subtree 317836
# adding branch 317836
# Parsing subtree 317943
# adding branch 317943
# Finishing...
# Parsing tree 29159
# Parsing subtree 29159
# breaking
# adding branch 29159
# Parsing subtree 109584
# breaking
# adding branch 109584
# Parsing subtree 702847
# breaking
# adding branch 702847
# Parsing subtree 1017239
# adding branch 1017239
# Parsing subtree 1017261
# adding branch 1017261
# Parsing subtree 702886
# adding branch 702886
# Parsing subtree 109620
# adding branch 109620
# Finishing...
# Parsing tree 32784
# Parsing subtree 32784
# breaking
# adding branch 32784
# Parsing subtree 181372
# adding branch 181372
# Parsing subtree 181360
# breaking
# adding branch 181360
# Parsing subtree 255301
# breaking
# adding branch 255301
# Parsing subtree 382140
# breaking
# adding branch 382140
# Parsing subtree 487318
# adding branch 487318
# Parsing subtree 487361
# breaking
# adding branch 487361
# Parsing subtree 546589
# breaking
# adding branch 546589
# Parsing subtree 600077
# adding branch 600077
# Parsing subtree 600119
# breaking
# adding branch 600119
# Parsing subtree 623458
# adding branch 623458
# Parsing subtree 623420
# adding branch 623420
# Parsing subtree 546642
# adding branch 546642
# Parsing subtree 382102
# adding branch 382102
# Parsing subtree 255247
# adding branch 255247
# Finishing...
# Parsing tree 32526
# Parsing subtree 32526
# breaking
# adding branch 32526
# Parsing subtree 516761
# adding branch 516761
# Parsing subtree 516762
# breaking
# adding branch 516762
# Parsing subtree 676579
# breaking
# adding branch 676579
# Parsing subtree 1082524
# adding branch 1082524
# Parsing subtree 1082620
# adding branch 1082620
# Parsing subtree 676569
# adding branch 676569
# Finishing...
# Parsing tree 34197
# Parsing subtree 34197
# adding branch 34197
# Finishing...
# Parsing tree 34460
# Parsing subtree 34460
# adding branch 34460
# Finishing...
# Parsing tree 29991
# Parsing subtree 29991
# adding branch 29991
# Finishing...
# Parsing tree 32299
# Parsing subtree 32299
# breaking
# adding branch 32299
# Parsing subtree 346918
# adding branch 346918
# Parsing subtree 346969
# adding branch 346969
# Finishing...
# Parsing tree 32871
# Parsing subtree 32871
# adding branch 32871
# Finishing...
# Parsing tree 33931
# Parsing subtree 33931
# breaking
# adding branch 33931
# Parsing subtree 1035984
# adding branch 1035984
# Parsing subtree 1036079
# adding branch 1036079
# Finishing...
# Parsing tree 33655
# Parsing subtree 33655
# breaking
# adding branch 33655
# Parsing subtree 511725
# adding branch 511725
# Parsing subtree 511741
# adding branch 511741
# Finishing...
# Parsing tree 34200
# Parsing subtree 34200
# adding branch 34200
# Finishing...
# Parsing tree 34504
# Parsing subtree 34504
# breaking
# adding branch 34504
# Parsing subtree 274084
# breaking
# adding branch 274084
# Parsing subtree 536353
# adding branch 536353
# Parsing subtree 536352
# breaking
# adding branch 536352
# Parsing subtree 571971
# adding branch 571971
# Parsing subtree 571947
# adding branch 571947
# Parsing subtree 274113
# adding branch 274113
# Finishing...
# Parsing tree 34478
# Parsing subtree 34478
# adding branch 34478
# Finishing...
# Parsing tree 32614
# Parsing subtree 32614
# breaking
# adding branch 32614
# Parsing subtree 324539
# adding branch 324539
# Parsing subtree 324515
# adding branch 324515
# Finishing...
# Parsing tree 32146
# Parsing subtree 32146
# adding branch 32146
# Finishing...
# Parsing tree 33414
# Parsing subtree 33414
# breaking
# adding branch 33414
# Parsing subtree 400042
# adding branch 400042
# Parsing subtree 399978
# adding branch 399978
# Finishing...
# Parsing tree 31684
# Parsing subtree 31684
# adding branch 31684
# Finishing...
# Parsing tree 32887
# Parsing subtree 32887
# adding branch 32887
# Finishing...
# Parsing tree 31722
# Parsing subtree 31722
# adding branch 31722
# Finishing...
# Parsing tree 33451
# Parsing subtree 33451
# adding branch 33451
# Finishing...
# Parsing tree 32353
# Parsing subtree 32353
# breaking
# adding branch 32353
# Parsing subtree 823683
# adding branch 823683
# Parsing subtree 823690
# adding branch 823690
# Finishing...
# Parsing tree 32912
# Parsing subtree 32912
# adding branch 32912
# Finishing...
# Parsing tree 34749
# Parsing subtree 34749
# adding branch 34749
# Finishing...
# Parsing tree 28085
# Parsing subtree 28085
# adding branch 28085
# Finishing...
# Parsing tree 32630
# Parsing subtree 32630
# breaking
# adding branch 32630
# Parsing subtree 564445
# breaking
# adding branch 564445
# Parsing subtree 629230
# adding branch 629230
# Parsing subtree 629152
# adding branch 629152
# Parsing subtree 564488
# breaking
# adding branch 564488
# Parsing subtree 582210
# adding branch 582210
# Parsing subtree 582126
# breaking
# adding branch 582126
# Parsing subtree 676613
# breaking
# adding branch 676613
# Parsing subtree 712146
# adding branch 712146
# Parsing subtree 712075
# breaking
# adding branch 712075
# Parsing subtree 891794
# breaking
# adding branch 891794
# Parsing subtree 925949
# adding branch 925949
# Parsing subtree 925948
# breaking
# adding branch 925948
# Parsing subtree 1007446
# adding branch 1007446
# Parsing subtree 1007478
# adding branch 1007478
# Parsing subtree 891827
# adding branch 891827
# Parsing subtree 676578
# adding branch 676578
# Finishing...
# Parsing tree 34251
# Parsing subtree 34251
# breaking
# adding branch 34251
# Parsing subtree 357024
# breaking
# adding branch 357024
# Parsing subtree 784297
# breaking
# adding branch 784297
# Parsing subtree 870067
# adding branch 870067
# Parsing subtree 870187
# adding branch 870187
# Parsing subtree 784311
# adding branch 784311
# Parsing subtree 356931
# adding branch 356931
# Finishing...
# Parsing tree 30079
# Parsing subtree 30079
# breaking
# adding branch 30079
# Parsing subtree 531921
# adding branch 531921
# Parsing subtree 531885
# adding branch 531885
# Finishing...
# Parsing tree 32835
# Parsing subtree 32835
# breaking
# adding branch 32835
# Parsing subtree 376483
# adding branch 376483
# Parsing subtree 376507
# breaking
# adding branch 376507
# Parsing subtree 641313
# adding branch 641313
# Parsing subtree 641322
# adding branch 641322
# Finishing...
# Parsing tree 29252
# Parsing subtree 29252
# breaking
# adding branch 29252
# Parsing subtree 138116
# breaking
# adding branch 138116
# Parsing subtree 625824
# breaking
# adding branch 625824
# Parsing subtree 702935
# breaking
# adding branch 702935
# Parsing subtree 819991
# adding branch 819991
# Parsing subtree 820035
# adding branch 820035
# Parsing subtree 702929
# adding branch 702929
# Parsing subtree 625825
# adding branch 625825
# Parsing subtree 138097
# adding branch 138097
# Finishing...
# Parsing tree 33495
# Parsing subtree 33495
# adding branch 33495
# Finishing...
# Parsing tree 34549
# Parsing subtree 34549
# adding branch 34549
# Finishing...
# Parsing tree 29001
# Parsing subtree 29001
# adding branch 29001
# Finishing...
# Parsing tree 34029
# Parsing subtree 34029
# breaking
# adding branch 34029
# Parsing subtree 547779
# adding branch 547779
# Parsing subtree 547814
# breaking
# adding branch 547814
# Parsing subtree 913870
# adding branch 913870
# Parsing subtree 913871
# adding branch 913871
# Finishing...
# Parsing tree 29471
# Parsing subtree 29471
# adding branch 29471
# Finishing...
# Parsing tree 33777
# Parsing subtree 33777
# breaking
# adding branch 33777
# Parsing subtree 330932
# adding branch 330932
# Parsing subtree 330960
# breaking
# adding branch 330960
# Parsing subtree 583119
# adding branch 583119
# Parsing subtree 583154
# breaking
# adding branch 583154
# Parsing subtree 671774
# breaking
# adding branch 671774
# Parsing subtree 683523
# adding branch 683523
# Parsing subtree 683496
# adding branch 683496
# Parsing subtree 671792
# adding branch 671792
# Finishing...
# Parsing tree 34757
# Parsing subtree 34757
# adding branch 34757
# Finishing...
# Parsing tree 31723
# Parsing subtree 31723
# adding branch 31723
# Finishing...
# Parsing tree 32907
# Parsing subtree 32907
# adding branch 32907
# Finishing...
# Parsing tree 31052
# Parsing subtree 31052
# breaking
# adding branch 31052
# Parsing subtree 704506
# breaking
# adding branch 704506
# Parsing subtree 896070
# breaking
# adding branch 896070
# Parsing subtree 1153200
# adding branch 1153200
# Parsing subtree 1153091
# breaking
# adding branch 1153091
# Parsing subtree 1212521
# adding branch 1212521
# Parsing subtree 1212598
# adding branch 1212598
# Parsing subtree 896296
# adding branch 896296
# Parsing subtree 704525
# adding branch 704525
# Finishing...
# Parsing tree 29286
# Parsing subtree 29286
# breaking
# adding branch 29286
# Parsing subtree 58873
# adding branch 58873
# Parsing subtree 58872
# adding branch 58872
# Finishing...
# Parsing tree 31955
# Parsing subtree 31955
# adding branch 31955
# Finishing...
# Parsing tree 32667
# Parsing subtree 32667
# breaking
# adding branch 32667
# Parsing subtree 352935
# breaking
# adding branch 352935
# Parsing subtree 629175
# adding branch 629175
# Parsing subtree 629254
# breaking
# adding branch 629254
# Parsing subtree 796008
# breaking
# adding branch 796008
# Parsing subtree 1133269
# breaking
# adding branch 1133269
# Parsing subtree 1197558
# adding branch 1197558
# Parsing subtree 1197609
# breaking
# adding branch 1197609
# Parsing subtree 1469627
# breaking
# adding branch 1469627
# Parsing subtree 1646673
# breaking
# adding branch 1646673
# Parsing subtree 1771409
# adding branch 1771409
# Parsing subtree 1771387
# adding branch 1771387
# Parsing subtree 1646728
# adding branch 1646728
# Parsing subtree 1469711
# adding branch 1469711
# Parsing subtree 1133268
# adding branch 1133268
# Parsing subtree 796009
# adding branch 796009
# Parsing subtree 352936
# adding branch 352936
# Finishing...
# Parsing tree 32389
# Parsing subtree 32389
# adding branch 32389
# Finishing...
# Parsing tree 29819
# Parsing subtree 29819
# breaking
# adding branch 29819
# Parsing subtree 567505
# adding branch 567505
# Parsing subtree 567448
# breaking
# adding branch 567448
# Parsing subtree 591330
# adding branch 591330
# Parsing subtree 591318
# breaking
# adding branch 591318
# Parsing subtree 602938
# adding branch 602938
# Parsing subtree 602869
# breaking
# adding branch 602869
# Parsing subtree 691302
# breaking
# adding branch 691302
# Parsing subtree 741900
# adding branch 741900
# Parsing subtree 742009
# adding branch 742009
# Parsing subtree 691368
# adding branch 691368
# Finishing...
# Parsing tree 29477
# Parsing subtree 29477
# breaking
# adding branch 29477
# Parsing subtree 407945
# adding branch 407945
# Parsing subtree 407905
# breaking
# adding branch 407905
# Parsing subtree 626041
# breaking
# adding branch 626041
# Parsing subtree 644010
# breaking
# adding branch 644010
# Parsing subtree 970332
# adding branch 970332
# Parsing subtree 970311
# adding branch 970311
# Parsing subtree 644009
# adding branch 644009
# Parsing subtree 626088
# adding branch 626088
# Finishing...
# Parsing tree 29031
# Parsing subtree 29031
# adding branch 29031
# Finishing...
# Parsing tree 30049
# Parsing subtree 30049
# adding branch 30049
# Finishing...
# Parsing tree 32969
# Parsing subtree 32969
# breaking
# adding branch 32969
# Parsing subtree 647431
# adding branch 647431
# Parsing subtree 647376
# breaking
# adding branch 647376
# Parsing subtree 676952
# adding branch 676952
# Parsing subtree 676951
# adding branch 676951
# Finishing...
# Parsing tree 31557
# Parsing subtree 31557
# adding branch 31557
# Finishing...
# Parsing tree 30779
# Parsing subtree 30779
# adding branch 30779
# Finishing...
# Parsing tree 34085
# Parsing subtree 34085
# breaking
# adding branch 34085
# Parsing subtree 535926
# adding branch 535926
# Parsing subtree 535879
# breaking
# adding branch 535879
# Parsing subtree 734521
# adding branch 734521
# Parsing subtree 734443
# adding branch 734443
# Finishing...
# Parsing tree 34811
# Parsing subtree 34811
# adding branch 34811
# Finishing...
# Parsing tree 40398
# Parsing subtree 40398
# breaking
# adding branch 40398
# Parsing subtree 401161
# adding branch 401161
# Parsing subtree 401162
# adding branch 401162
# Finishing...
# Parsing tree 38755
# Parsing subtree 38755
# adding branch 38755
# Finishing...
# Parsing tree 33207
# Parsing subtree 33207
# adding branch 33207
# Finishing...
# Parsing tree 34834
# Parsing subtree 34834
# adding branch 34834
# Finishing...
# Parsing tree 34344
# Parsing subtree 34344
# adding branch 34344
# Finishing...
# Parsing tree 33335
# Parsing subtree 33335
# adding branch 33335
# Finishing...
# Parsing tree 34624
# Parsing subtree 34624
# adding branch 34624
# Finishing...
# Parsing tree 29586
# Parsing subtree 29586
# adding branch 29586
# Finishing...
# Parsing tree 33427
# Parsing subtree 33427
# adding branch 33427
# Finishing...
# Parsing tree 29845
# Parsing subtree 29845
# adding branch 29845
# Finishing...
# Parsing tree 34977
# Parsing subtree 34977
# adding branch 34977
# Finishing...
# Parsing tree 34475
# Parsing subtree 34475
# adding branch 34475
# Finishing...
# Parsing tree 29624
# Parsing subtree 29624
# adding branch 29624
# Finishing...
# Parsing tree 34744
# Parsing subtree 34744
# adding branch 34744
# Finishing...
# Parsing tree 34754
# Parsing subtree 34754
# adding branch 34754
# Finishing...
# Parsing tree 32212
# Parsing subtree 32212
# adding branch 32212
# Finishing...
# Parsing tree 33748
# Parsing subtree 33748
# adding branch 33748
# Finishing...
# Parsing tree 34792
# Parsing subtree 34792
# adding branch 34792
# Finishing...
# Parsing tree 29936
# Parsing subtree 29936
# adding branch 29936
# Finishing...
# Parsing tree 34288
# Parsing subtree 34288
# adding branch 34288
# Finishing...
# Parsing tree 41508
# Parsing subtree 41508
# adding branch 41508
# Finishing...
# Parsing tree 22144
# Parsing subtree 22144
# adding branch 22144
# Finishing...
# Parsing tree 57912
# Parsing subtree 57912
# adding branch 57912
# Finishing...
# Parsing tree 58465
# Parsing subtree 58465
# breaking
# adding branch 58465
# Parsing subtree 75598
# adding branch 75598
# Parsing subtree 75597
# breaking
# adding branch 75597
# Parsing subtree 154858
# adding branch 154858
# Parsing subtree 154857
# adding branch 154857
# Finishing...
# Parsing tree 57483
# Parsing subtree 57483
# adding branch 57483
# Finishing...
# Parsing tree 57497
# Parsing subtree 57497
# breaking
# adding branch 57497
# Parsing subtree 63271
# adding branch 63271
# Parsing subtree 63272
# adding branch 63272
# Finishing...
# Parsing tree 52652
# Parsing subtree 52652
# adding branch 52652
# Finishing...
# Parsing tree 52684
# Parsing subtree 52684
# adding branch 52684
# Finishing...
# Parsing tree 53472
# Parsing subtree 53472
# adding branch 53472
# Finishing...
# Parsing tree 64264
# Parsing subtree 64264
# adding branch 64264
# Finishing...
# Parsing tree 68527
# Parsing subtree 68527
# breaking
# adding branch 68527
# Parsing subtree 79905
# adding branch 79905
# Parsing subtree 79904
# adding branch 79904
# Finishing...
# Parsing tree 58656
# Parsing subtree 58656
# adding branch 58656
# Finishing...
# Parsing tree 69504
# Parsing subtree 69504
# adding branch 69504
# Finishing...
# Parsing tree 69284
# Parsing subtree 69284
# adding branch 69284
# Finishing...
# Parsing tree 63020
# Parsing subtree 63020
# adding branch 63020
# Finishing...
# Parsing tree 58925
# Parsing subtree 58925
# adding branch 58925
# Finishing...
# Parsing tree 69514
# Parsing subtree 69514
# adding branch 69514
# Finishing...
# Parsing tree 69525
# Parsing subtree 69525
# adding branch 69525
# Finishing...
# Parsing tree 60250
# Parsing subtree 60250
# adding branch 60250
# Finishing...
# Parsing tree 58716
# Parsing subtree 58716
# adding branch 58716
# Finishing...
# Parsing tree 64101
# Parsing subtree 64101
# adding branch 64101
# Finishing...
# Parsing tree 64526
# Parsing subtree 64526
# adding branch 64526
# Finishing...
# Parsing tree 66067
# Parsing subtree 66067
# adding branch 66067
# Finishing...
# Parsing tree 63092
# Parsing subtree 63092
# adding branch 63092
# Finishing...
# Parsing tree 63098
# Parsing subtree 63098
# adding branch 63098
# Finishing...
# Parsing tree 58750
# Parsing subtree 58750
# adding branch 58750
# Finishing...
# Parsing tree 69387
# Parsing subtree 69387
# adding branch 69387
# Finishing...
# Parsing tree 68435
# Parsing subtree 68435
# adding branch 68435
# Finishing...
# Parsing tree 63655
# Parsing subtree 63655
# adding branch 63655
# Finishing...
# Parsing tree 58796
# Parsing subtree 58796
# adding branch 58796
# Finishing...
# Parsing tree 64356
# Parsing subtree 64356
# adding branch 64356
# Finishing...
# Parsing tree 68437
# Parsing subtree 68437
# adding branch 68437
# Finishing...
# Parsing tree 61874
# Parsing subtree 61874
# adding branch 61874
# Finishing...
# Parsing tree 63925
# Parsing subtree 63925
# adding branch 63925
# Finishing...
# Parsing tree 64371
# Parsing subtree 64371
# adding branch 64371
# Finishing...
# Parsing tree 62911
# Parsing subtree 62911
# adding branch 62911
# Finishing...
# Parsing tree 69148
# Parsing subtree 69148
# adding branch 69148
# Finishing...
# Parsing tree 64202
# Parsing subtree 64202
# adding branch 64202
# Finishing...
# Parsing tree 64208
# Parsing subtree 64208
# adding branch 64208
# Finishing...
# Parsing tree 58850
# Parsing subtree 58850
# adding branch 58850
# Finishing...
# Parsing tree 74495
# Parsing subtree 74495
# adding branch 74495
# Finishing...
# Parsing tree 87196
# Parsing subtree 87196
# adding branch 87196
# Finishing...
# Parsing tree 81163
# Parsing subtree 81163
# adding branch 81163
# Finishing...
# Parsing tree 91705
# Parsing subtree 91705
# adding branch 91705
# Finishing...
# Parsing tree 84250
# Parsing subtree 84250
# adding branch 84250
# Finishing...
# Parsing tree 81437
# Parsing subtree 81437
# adding branch 81437
# Finishing...
# Parsing tree 80517
# Parsing subtree 80517
# adding branch 80517
# Finishing...
# Parsing tree 91132
# Parsing subtree 91132
# adding branch 91132
# Finishing...
# Parsing tree 90870
# Parsing subtree 90870
# adding branch 90870
# Finishing...
# Parsing tree 91172
# Parsing subtree 91172
# adding branch 91172
# Finishing...
# Parsing tree 86415
# Parsing subtree 86415
# adding branch 86415
# Finishing...
# Parsing tree 85408
# Parsing subtree 85408
# adding branch 85408
# Finishing...
# Parsing tree 80405
# Parsing subtree 80405
# adding branch 80405
# Finishing...
# Parsing tree 85462
# Parsing subtree 85462
# adding branch 85462
# Finishing...
# Parsing tree 90079
# Parsing subtree 90079
# adding branch 90079
# Finishing...
# Parsing tree 91349
# Parsing subtree 91349
# adding branch 91349
# Finishing...
# Parsing tree 91019
# Parsing subtree 91019
# adding branch 91019
# Finishing...
# Parsing tree 91983
# Parsing subtree 91983
# adding branch 91983
# Finishing...
# Parsing tree 108938
# Parsing subtree 108938
# adding branch 108938
# Finishing...
# Parsing tree 108945
# Parsing subtree 108945
# adding branch 108945
# Finishing...
# Parsing tree 98466
# Parsing subtree 98466
# adding branch 98466
# Finishing...
# Parsing tree 99280
# Parsing subtree 99280
# adding branch 99280
# Finishing...
# Parsing tree 91537
# Parsing subtree 91537
# adding branch 91537
# Finishing...
# Parsing tree 90866
# Parsing subtree 90866
# adding branch 90866
# Finishing...
# Parsing tree 91154
# Parsing subtree 91154
# adding branch 91154
# Finishing...
# Parsing tree 91444
# Parsing subtree 91444
# adding branch 91444
# Finishing...
# Parsing tree 92035
# Parsing subtree 92035
# adding branch 92035
# Finishing...
# Parsing tree 88289
# Parsing subtree 88289
# adding branch 88289
# Finishing...
# Parsing tree 91364
# Parsing subtree 91364
# adding branch 91364
# Finishing...
# Parsing tree 80656
# Parsing subtree 80656
# adding branch 80656
# Finishing...
# Parsing tree 107038
# Parsing subtree 107038
# adding branch 107038
# Finishing...
# Parsing tree 106069
# Parsing subtree 106069
# adding branch 106069
# Finishing...
# Parsing tree 113758
# Parsing subtree 113758
# adding branch 113758
# Finishing...
# Parsing tree 107692
# Parsing subtree 107692
# adding branch 107692
# Finishing...
# Parsing tree 112091
# Parsing subtree 112091
# adding branch 112091
# Finishing...
# Parsing tree 119302
# Parsing subtree 119302
# adding branch 119302
# Finishing...
# Parsing tree 115520
# Parsing subtree 115520
# adding branch 115520
# Finishing...
# Parsing tree 137816
# Parsing subtree 137816
# adding branch 137816
# Finishing...
# Parsing tree 150925
# Parsing subtree 150925
# adding branch 150925
# Finishing...
# Parsing tree 151463
# Parsing subtree 151463
# adding branch 151463
# Finishing...
# Parsing tree 149452
# Parsing subtree 149452
# breaking
# adding branch 149452
# Parsing subtree 332453
# breaking
# adding branch 332453
# Parsing subtree 413456
# breaking
# adding branch 413456
# Parsing subtree 696778
# adding branch 696778
# Parsing subtree 696757
# breaking
# adding branch 696757
# Parsing subtree 888044
# adding branch 888044
# Parsing subtree 888060
# adding branch 888060
# Parsing subtree 413465
# breaking
# adding branch 413465
# Parsing subtree 442509
# adding branch 442509
# Parsing subtree 442493
# breaking
# adding branch 442493
# Parsing subtree 673343
# adding branch 673343
# Parsing subtree 673362
# adding branch 673362
# Parsing subtree 332498
# adding branch 332498
# Finishing...
# Parsing tree 145301
# Parsing subtree 145301
# adding branch 145301
# Finishing...
# Parsing tree 147384
# Parsing subtree 147384
# adding branch 147384
# Finishing...
# Parsing tree 147782
# Parsing subtree 147782
# adding branch 147782
# Finishing...
# Parsing tree 143947
# Parsing subtree 143947
# breaking
# adding branch 143947
# Parsing subtree 189481
# adding branch 189481
# Parsing subtree 189517
# breaking
# adding branch 189517
# Parsing subtree 372933
# adding branch 372933
# Parsing subtree 372967
# breaking
# adding branch 372967
# Parsing subtree 472377
# adding branch 472377
# Parsing subtree 472335
# adding branch 472335
# Finishing...
# Parsing tree 176301
# Parsing subtree 176301
# adding branch 176301
# Finishing...
# Parsing tree 172781
# Parsing subtree 172781
# breaking
# adding branch 172781
# Parsing subtree 217907
# adding branch 217907
# Parsing subtree 217906
# adding branch 217906
# Finishing...
# Parsing tree 194958
# Parsing subtree 194958
# adding branch 194958
# Finishing...
# Parsing tree 199992
# Parsing subtree 199992
# adding branch 199992
# Finishing...
# Parsing tree 204893
# Parsing subtree 204893
# breaking
# adding branch 204893
# Parsing subtree 763721
# adding branch 763721
# Parsing subtree 763809
# adding branch 763809
# Finishing...
# Parsing tree 216977
# Parsing subtree 216977
# adding branch 216977
# Finishing...
# Parsing tree 211645
# Parsing subtree 211645
# adding branch 211645
# Finishing...
# Parsing tree 216133
# Parsing subtree 216133
# adding branch 216133
# Finishing...
# Parsing tree 228126
# Parsing subtree 228126
# adding branch 228126
# Finishing...
# Parsing tree 220154
# Parsing subtree 220154
# adding branch 220154
# Finishing...
# Parsing tree 245113
# Parsing subtree 245113
# adding branch 245113
# Finishing...
# Parsing tree 249112
# Parsing subtree 249112
# adding branch 249112
# Finishing...
# Parsing tree 243462
# Parsing subtree 243462
# adding branch 243462
# Finishing...
# Parsing tree 242538
# Parsing subtree 242538
# adding branch 242538
# Finishing...
# Parsing tree 68434
# Parsing subtree 68434
# adding branch 68434
# Finishing...
# Parsing tree 251348
# Parsing subtree 251348
# adding branch 251348
# Finishing...
# Parsing tree 271782
# Parsing subtree 271782
# adding branch 271782
# Finishing...
# Parsing tree 263933
# Parsing subtree 263933
# adding branch 263933
# Finishing...
# Parsing tree 290418
# Parsing subtree 290418
# adding branch 290418
# Finishing...
# Parsing tree 293928
# Parsing subtree 293928
# breaking
# adding branch 293928
# Parsing subtree 363005
# adding branch 363005
# Parsing subtree 363089
# breaking
# adding branch 363089
# Parsing subtree 397936
# adding branch 397936
# Parsing subtree 398024
# breaking
# adding branch 398024
# Parsing subtree 479942
# adding branch 479942
# Parsing subtree 479972
# adding branch 479972
# Finishing...
# Parsing tree 298645
# Parsing subtree 298645
# adding branch 298645
# Finishing...
# Parsing tree 302384
# Parsing subtree 302384
# breaking
# adding branch 302384
# Parsing subtree 356419
# adding branch 356419
# Parsing subtree 356360
# adding branch 356360
# Finishing...
# Parsing tree 302776
# Parsing subtree 302776
# adding branch 302776
# Finishing...
# Parsing tree 307736
# Parsing subtree 307736
# adding branch 307736
# Finishing...
# Parsing tree 310022
# Parsing subtree 310022
# adding branch 310022
# Finishing...
# Parsing tree 323975
# Parsing subtree 323975
# breaking
# adding branch 323975
# Parsing subtree 676162
# breaking
# adding branch 676162
# Parsing subtree 754944
# breaking
# adding branch 754944
# Parsing subtree 1013857
# adding branch 1013857
# Parsing subtree 1013792
# adding branch 1013792
# Parsing subtree 754945
# adding branch 754945
# Parsing subtree 676161
# adding branch 676161
# Finishing...
# Parsing tree 313846
# Parsing subtree 313846
# adding branch 313846
# Finishing...
# Parsing tree 332081
# Parsing subtree 332081
# adding branch 332081
# Finishing...
# Parsing tree 330596
# Parsing subtree 330596
# adding branch 330596
# Finishing...
# Parsing tree 363740
# Parsing subtree 363740
# adding branch 363740
# Finishing...
# Parsing tree 375231
# Parsing subtree 375231
# adding branch 375231
# Finishing...
# Parsing tree 374368
# Parsing subtree 374368
# adding branch 374368
# Finishing...
# Parsing tree 395240
# Parsing subtree 395240
# adding branch 395240
# Finishing...
# Parsing tree 413222
# Parsing subtree 413222
# adding branch 413222
# Finishing...
# Parsing tree 401038
# Parsing subtree 401038
# adding branch 401038
# Finishing...
# Parsing tree 397561
# Parsing subtree 397561
# adding branch 397561
# Finishing...
# Parsing tree 407353
# Parsing subtree 407353
# adding branch 407353
# Finishing...
# Parsing tree 408265
# Parsing subtree 408265
# adding branch 408265
# Finishing...
# Parsing tree 425566
# Parsing subtree 425566
# adding branch 425566
# Finishing...
# Parsing tree 433244
# Parsing subtree 433244
# breaking
# adding branch 433244
# Parsing subtree 610417
# adding branch 610417
# Parsing subtree 610516
# breaking
# adding branch 610516
# Parsing subtree 622309
# adding branch 622309
# Parsing subtree 622290
# breaking
# adding branch 622290
# Parsing subtree 669731
# breaking
# adding branch 669731
# Parsing subtree 729463
# adding branch 729463
# Parsing subtree 729585
# breaking
# adding branch 729585
# Parsing subtree 813486
# adding branch 813486
# Parsing subtree 813577
# breaking
# adding branch 813577
# Parsing subtree 856411
# adding branch 856411
# Parsing subtree 856497
# breaking
# adding branch 856497
# Parsing subtree 924857
# adding branch 924857
# Parsing subtree 924856
# adding branch 924856
# Parsing subtree 669749
# adding branch 669749
# Finishing...
# Parsing tree 440672
# Parsing subtree 440672
# adding branch 440672
# Finishing...
# Parsing tree 449083
# Parsing subtree 449083
# adding branch 449083
# Finishing...
# Parsing tree 452451
# Parsing subtree 452451
# adding branch 452451
# Finishing...
# Parsing tree 465408
# Parsing subtree 465408
# breaking
# adding branch 465408
# Parsing subtree 777943
# adding branch 777943
# Parsing subtree 777900
# breaking
# adding branch 777900
# Parsing subtree 791369
# adding branch 791369
# Parsing subtree 791350
# breaking
# adding branch 791350
# Parsing subtree 934866
# adding branch 934866
# Parsing subtree 934865
# breaking
# adding branch 934865
# Parsing subtree 969086
# adding branch 969086
# Parsing subtree 969087
# breaking
# adding branch 969087
# Parsing subtree 1057165
# breaking
# adding branch 1057165
# Parsing subtree 1149349
# adding branch 1149349
# Parsing subtree 1149199
# adding branch 1149199
# Parsing subtree 1057132
# adding branch 1057132
# Finishing...
# Parsing tree 460581
# Parsing subtree 460581
# adding branch 460581
# Finishing...
# Parsing tree 471410
# Parsing subtree 471410
# adding branch 471410
# Finishing...
# Parsing tree 472843
# Parsing subtree 472843
# adding branch 472843
# Finishing...
# Parsing tree 477586
# Parsing subtree 477586
# adding branch 477586
# Finishing...
# Parsing tree 483497
# Parsing subtree 483497
# adding branch 483497
# Finishing...
# Parsing tree 505017
# Parsing subtree 505017
# adding branch 505017
# Finishing...
# Parsing tree 514104
# Parsing subtree 514104
# breaking
# adding branch 514104
# Parsing subtree 644336
# adding branch 644336
# Parsing subtree 644371
# breaking
# adding branch 644371
# Parsing subtree 772980
# adding branch 772980
# Parsing subtree 772894
# adding branch 772894
# Finishing...
# Parsing tree 517729
# Parsing subtree 517729
# adding branch 517729
# Finishing...
# Parsing tree 518510
# Parsing subtree 518510
# adding branch 518510
# Finishing...
# Parsing tree 517574
# Parsing subtree 517574
# adding branch 517574
# Finishing...
# Parsing tree 513771
# Parsing subtree 513771
# adding branch 513771
# Finishing...
# Parsing tree 531799
# Parsing subtree 531799
# adding branch 531799
# Finishing...
# Parsing tree 531817
# Parsing subtree 531817
# adding branch 531817
# Finishing...
# Parsing tree 535453
# Parsing subtree 535453
# adding branch 535453
# Finishing...
# Parsing tree 535745
# Parsing subtree 535745
# adding branch 535745
# Finishing...
# Parsing tree 537706
# Parsing subtree 537706
# adding branch 537706
# Finishing...
# Parsing tree 537218
# Parsing subtree 537218
# breaking
# adding branch 537218
# Parsing subtree 714850
# breaking
# adding branch 714850
# Parsing subtree 1137342
# adding branch 1137342
# Parsing subtree 1137322
# adding branch 1137322
# Parsing subtree 714818
# adding branch 714818
# Finishing...
# Parsing tree 538603
# Parsing subtree 538603
# adding branch 538603
# Finishing...
# Parsing tree 537080
# Parsing subtree 537080
# adding branch 537080
# Finishing...
# Parsing tree 543833
# Parsing subtree 543833
# adding branch 543833
# Finishing...
# Parsing tree 547051
# Parsing subtree 547051
# adding branch 547051
# Finishing...
# Parsing tree 550430
# Parsing subtree 550430
# adding branch 550430
# Finishing...
# Parsing tree 559093
# Parsing subtree 559093
# adding branch 559093
# Finishing...
# Parsing tree 576038
# Parsing subtree 576038
# adding branch 576038
# Finishing...
# Parsing tree 574093
# Parsing subtree 574093
# adding branch 574093
# Finishing...
# Parsing tree 573354
# Parsing subtree 573354
# adding branch 573354
# Finishing...
# Parsing tree 593568
# Parsing subtree 593568
# adding branch 593568
# Finishing...
# Parsing tree 601089
# Parsing subtree 601089
# adding branch 601089
# Finishing...
# Parsing tree 606466
# Parsing subtree 606466
# adding branch 606466
# Finishing...
# Parsing tree 607315
# Parsing subtree 607315
# adding branch 607315
# Finishing...
# Parsing tree 607198
# Parsing subtree 607198
# adding branch 607198
# Finishing...
# Parsing tree 613891
# Parsing subtree 613891
# adding branch 613891
# Finishing...
# Parsing tree 608326
# Parsing subtree 608326
# adding branch 608326
# Finishing...
# Parsing tree 613925
# Parsing subtree 613925
# adding branch 613925
# Finishing...
# Parsing tree 619123
# Parsing subtree 619123
# adding branch 619123
# Finishing...
# Parsing tree 624129
# Parsing subtree 624129
# adding branch 624129
# Finishing...
# Parsing tree 620586
# Parsing subtree 620586
# adding branch 620586
# Finishing...
# Parsing tree 628170
# Parsing subtree 628170
# adding branch 628170
# Finishing...
# Parsing tree 626546
# Parsing subtree 626546
# adding branch 626546
# Finishing...
# Parsing tree 635673
# Parsing subtree 635673
# breaking
# adding branch 635673
# Parsing subtree 919994
# adding branch 919994
# Parsing subtree 919898
# adding branch 919898
# Finishing...
# Parsing tree 632629
# Parsing subtree 632629
# adding branch 632629
# Finishing...
# Parsing tree 636593
# Parsing subtree 636593
# adding branch 636593
# Finishing...
# Parsing tree 638402
# Parsing subtree 638402
# adding branch 638402
# Finishing...
# Parsing tree 642801
# Parsing subtree 642801
# adding branch 642801
# Finishing...
# Parsing tree 656072
# Parsing subtree 656072
# adding branch 656072
# Finishing...
# Parsing tree 665568
# Parsing subtree 665568
# adding branch 665568
# Finishing...
# Parsing tree 667945
# Parsing subtree 667945
# adding branch 667945
# Finishing...
# Parsing tree 673099
# Parsing subtree 673099
# breaking
# adding branch 673099
# Parsing subtree 747547
# adding branch 747547
# Parsing subtree 747548
# adding branch 747548
# Finishing...
# Parsing tree 668103
# Parsing subtree 668103
# adding branch 668103
# Finishing...
# Parsing tree 679059
# Parsing subtree 679059
# adding branch 679059
# Finishing...
# Parsing tree 695935
# Parsing subtree 695935
# breaking
# adding branch 695935
# Parsing subtree 719824
# breaking
# adding branch 719824
# Parsing subtree 962440
# adding branch 962440
# Parsing subtree 962429
# adding branch 962429
# Parsing subtree 719823
# adding branch 719823
# Finishing...
# Parsing tree 692164
# Parsing subtree 692164
# adding branch 692164
# Finishing...
# Parsing tree 707288
# Parsing subtree 707288
# adding branch 707288
# Finishing...
# Parsing tree 708602
# Parsing subtree 708602
# adding branch 708602
# Finishing...
# Parsing tree 708986
# Parsing subtree 708986
# adding branch 708986
# Finishing...
# Parsing tree 712363
# Parsing subtree 712363
# adding branch 712363
# Finishing...
# Parsing tree 716873
# Parsing subtree 716873
# adding branch 716873
# Finishing...
# Parsing tree 719702
# Parsing subtree 719702
# adding branch 719702
# Finishing...
# Parsing tree 718964
# Parsing subtree 718964
# adding branch 718964
# Finishing...
# Parsing tree 718826
# Parsing subtree 718826
# adding branch 718826
# Finishing...
# Parsing tree 721060
# Parsing subtree 721060
# adding branch 721060
# Finishing...
# Parsing tree 725685
# Parsing subtree 725685
# adding branch 725685
# Finishing...
# Parsing tree 724716
# Parsing subtree 724716
# adding branch 724716
# Finishing...
# Parsing tree 729654
# Parsing subtree 729654
# adding branch 729654
# Finishing...
# Parsing tree 730845
# Parsing subtree 730845
# adding branch 730845
# Finishing...
# Parsing tree 727054
# Parsing subtree 727054
# adding branch 727054
# Finishing...
# Parsing tree 734305
# Parsing subtree 734305
# adding branch 734305
# Finishing...
# Parsing tree 727751
# Parsing subtree 727751
# adding branch 727751
# Finishing...
# Parsing tree 732612
# Parsing subtree 732612
# adding branch 732612
# Finishing...
# Parsing tree 739348
# Parsing subtree 739348
# adding branch 739348
# Finishing...
# Parsing tree 745267
# Parsing subtree 745267
# breaking
# adding branch 745267
# Parsing subtree 898865
# adding branch 898865
# Parsing subtree 898909
# adding branch 898909
# Finishing...
# Parsing tree 751091
# Parsing subtree 751091
# adding branch 751091
# Finishing...
# Parsing tree 500687
# Parsing subtree 500687
# adding branch 500687
# Finishing...
# Parsing tree 751723
# Parsing subtree 751723
# breaking
# adding branch 751723
# Parsing subtree 826784
# adding branch 826784
# Parsing subtree 826783
# adding branch 826783
# Finishing...
# Parsing tree 763432
# Parsing subtree 763432
# adding branch 763432
# Finishing...
# Parsing tree 756776
# Parsing subtree 756776
# adding branch 756776
# Finishing...
# Parsing tree 751749
# Parsing subtree 751749
# adding branch 751749
# Finishing...
# Parsing tree 764735
# Parsing subtree 764735
# adding branch 764735
# Finishing...
# Parsing tree 764723
# Parsing subtree 764723
# adding branch 764723
# Finishing...
# Parsing tree 757553
# Parsing subtree 757553
# adding branch 757553
# Finishing...
# Parsing tree 751643
# Parsing subtree 751643
# adding branch 751643
# Finishing...
# Parsing tree 751651
# Parsing subtree 751651
# breaking
# adding branch 751651
# Parsing subtree 772124
# adding branch 772124
# Parsing subtree 772123
# adding branch 772123
# Finishing...
# Parsing tree 752517
# Parsing subtree 752517
# adding branch 752517
# Finishing...
# Parsing tree 751345
# Parsing subtree 751345
# adding branch 751345
# Finishing...
# Parsing tree 760140
# Parsing subtree 760140
# adding branch 760140
# Finishing...
# Parsing tree 751877
# Parsing subtree 751877
# breaking
# adding branch 751877
# Parsing subtree 997372
# adding branch 997372
# Parsing subtree 997373
# adding branch 997373
# Finishing...
# Parsing tree 760154
# Parsing subtree 760154
# adding branch 760154
# Finishing...
# Parsing tree 757591
# Parsing subtree 757591
# adding branch 757591
# Finishing...
# Parsing tree 755969
# Parsing subtree 755969
# adding branch 755969
# Finishing...
# Parsing tree 760060
# Parsing subtree 760060
# adding branch 760060
# Finishing...
# Parsing tree 760056
# Parsing subtree 760056
# adding branch 760056
# Finishing...
# Parsing tree 760054
# Parsing subtree 760054
# breaking
# adding branch 760054
# Parsing subtree 1129001
# adding branch 1129001
# Parsing subtree 1129002
# adding branch 1129002
# Finishing...
# Parsing tree 756847
# Parsing subtree 756847
# adding branch 756847
# Finishing...
# Parsing tree 760062
# Parsing subtree 760062
# breaking
# adding branch 760062
# Parsing subtree 785111
# breaking
# adding branch 785111
# Parsing subtree 1010260
# breaking
# adding branch 1010260
# Parsing subtree 1121568
# breaking
# adding branch 1121568
# Parsing subtree 1150868
# adding branch 1150868
# Parsing subtree 1150869
# breaking
# adding branch 1150869
# Parsing subtree 1355247
# adding branch 1355247
# Parsing subtree 1355246
# adding branch 1355246
# Parsing subtree 1121509
# adding branch 1121509
# Parsing subtree 1010324
# adding branch 1010324
# Parsing subtree 785057
# adding branch 785057
# Finishing...
# Parsing tree 751763
# Parsing subtree 751763
# adding branch 751763
# Finishing...
# Parsing tree 758572
# Parsing subtree 758572
# adding branch 758572
# Finishing...
# Parsing tree 762492
# Parsing subtree 762492
# adding branch 762492
# Finishing...
# Parsing tree 758159
# Parsing subtree 758159
# adding branch 758159
# Finishing...
# Parsing tree 754239
# Parsing subtree 754239
# adding branch 754239
# Finishing...
# Parsing tree 763527
# Parsing subtree 763527
# adding branch 763527
# Finishing...
# Parsing tree 764807
# Parsing subtree 764807
# adding branch 764807
# Finishing...
# Parsing tree 759555
# Parsing subtree 759555
# adding branch 759555
# Finishing...
# Parsing tree 764309
# Parsing subtree 764309
# adding branch 764309
# Finishing...
# Parsing tree 764841
# Parsing subtree 764841
# adding branch 764841
# Finishing...
# Parsing tree 752303
# Parsing subtree 752303
# adding branch 752303
# Finishing...
# Parsing tree 759579
# Parsing subtree 759579
# adding branch 759579
# Finishing...
# Parsing tree 754263
# Parsing subtree 754263
# adding branch 754263
# Finishing...
# Parsing tree 751567
# Parsing subtree 751567
# adding branch 751567
# Finishing...
# Parsing tree 759669
# Parsing subtree 759669
# adding branch 759669
# Finishing...
# Parsing tree 759655
# Parsing subtree 759655
# adding branch 759655
# Finishing...
# Parsing tree 753171
# Parsing subtree 753171
# adding branch 753171
# Finishing...
# Parsing tree 763359
# Parsing subtree 763359
# adding branch 763359
# Finishing...
# Parsing tree 760029
# Parsing subtree 760029
# adding branch 760029
# Finishing...
# Parsing tree 751473
# Parsing subtree 751473
# adding branch 751473
# Finishing...
# Parsing tree 751449
# Parsing subtree 751449
# breaking
# adding branch 751449
# Parsing subtree 771945
# adding branch 771945
# Parsing subtree 771944
# breaking
# adding branch 771944
# Parsing subtree 833152
# breaking
# adding branch 833152
# Parsing subtree 942587
# breaking
# adding branch 942587
# Parsing subtree 1010454
# adding branch 1010454
# Parsing subtree 1010453
# adding branch 1010453
# Parsing subtree 942586
# adding branch 942586
# Parsing subtree 833151
# adding branch 833151
# Finishing...
# Parsing tree 754872
# Parsing subtree 754872
# breaking
# adding branch 754872
# Parsing subtree 802402
# adding branch 802402
# Parsing subtree 802401
# adding branch 802401
# Finishing...
# Parsing tree 767078
# Parsing subtree 767078
# adding branch 767078
# Finishing...
# Parsing tree 754977
# Parsing subtree 754977
# adding branch 754977
# Finishing...
# Parsing tree 774943
# Parsing subtree 774943
# breaking
# adding branch 774943
# Parsing subtree 856473
# adding branch 856473
# Parsing subtree 856381
# breaking
# adding branch 856381
# Parsing subtree 938482
# breaking
# adding branch 938482
# Parsing subtree 965932
# breaking
# adding branch 965932
# Parsing subtree 999979
# adding branch 999979
# Parsing subtree 999980
# adding branch 999980
# Parsing subtree 965999
# adding branch 965999
# Parsing subtree 938481
# adding branch 938481
# Finishing...
# Parsing tree 772900
# Parsing subtree 772900
# adding branch 772900
# Finishing...
# Parsing tree 751897
# Parsing subtree 751897
# adding branch 751897
# Finishing...
# Parsing tree 776792
# Parsing subtree 776792
# adding branch 776792
# Finishing...
# Parsing tree 766881
# Parsing subtree 766881
# adding branch 766881
# Finishing...
# Parsing tree 770390
# Parsing subtree 770390
# adding branch 770390
# Finishing...
# Parsing tree 772482
# Parsing subtree 772482
# breaking
# adding branch 772482
# Parsing subtree 799448
# breaking
# adding branch 799448
# Parsing subtree 820177
# adding branch 820177
# Parsing subtree 820139
# breaking
# adding branch 820139
# Parsing subtree 874594
# adding branch 874594
# Parsing subtree 874503
# adding branch 874503
# Parsing subtree 799449
# breaking
# adding branch 799449
# Parsing subtree 863620
# adding branch 863620
# Parsing subtree 863622
# adding branch 863622
# Finishing...
# Parsing tree 776839
# Parsing subtree 776839
# breaking
# adding branch 776839
# Parsing subtree 845066
# adding branch 845066
# Parsing subtree 845086
# adding branch 845086
# Finishing...
# Parsing tree 769909
# Parsing subtree 769909
# adding branch 769909
# Finishing...
# Parsing tree 759557
# Parsing subtree 759557
# breaking
# adding branch 759557
# Parsing subtree 921664
# breaking
# adding branch 921664
# Parsing subtree 1037018
# adding branch 1037018
# Parsing subtree 1037019
# adding branch 1037019
# Parsing subtree 921663
# adding branch 921663
# Finishing...
# Parsing tree 768331
# Parsing subtree 768331
# adding branch 768331
# Finishing...
# Parsing tree 757382
# Parsing subtree 757382
# adding branch 757382
# Finishing...
# Parsing tree 772073
# Parsing subtree 772073
# adding branch 772073
# Finishing...
# Parsing tree 772320
# Parsing subtree 772320
# adding branch 772320
# Finishing...
# Parsing tree 751633
# Parsing subtree 751633
# adding branch 751633
# Finishing...
# Parsing tree 768829
# Parsing subtree 768829
# adding branch 768829
# Finishing...
# Parsing tree 771151
# Parsing subtree 771151
# adding branch 771151
# ...
# adding branch 1473066
# Finishing...
# Parsing tree 1466325
# Parsing subtree 1466325
# adding branch 1466325
# Finishing...
# Parsing tree 1465326
# Parsing subtree 1465326
# adding branch 1465326
# Finishing...
# Parsing tree 1477905
# Parsing subtree 1477905
# adding branch 1477905
# Finishing...
# Parsing tree 1477912
# Parsing subtree 1477912
# adding branch 1477912
# Finishing...
# Parsing tree 1485498
# Parsing subtree 1485498
# adding branch 1485498
# Finishing...
# Parsing tree 1474662
# Parsing subtree 1474662
# adding branch 1474662
# Finishing...
# Parsing tree 1487627
# Parsing subtree 1487627
# breaking
# adding branch 1487627
# Parsing subtree 1582741
# adding branch 1582741
# Parsing subtree 1582829
# adding branch 1582829
# Finishing...
# Parsing tree 1476025
# Parsing subtree 1476025
# adding branch 1476025
# Finishing...
# Parsing tree 1477541
# Parsing subtree 1477541
# adding branch 1477541
# Finishing...
# Parsing tree 1477074
# Parsing subtree 1477074
# adding branch 1477074
# Finishing...
# Parsing tree 1480899
# Parsing subtree 1480899
# adding branch 1480899
# Finishing...
# Parsing tree 1486956
# Parsing subtree 1486956
# breaking
# adding branch 1486956
# Parsing subtree 1527834
# adding branch 1527834
# Parsing subtree 1527835
# adding branch 1527835
# Finishing...
# Parsing tree 1503005
# Parsing subtree 1503005
# adding branch 1503005
# Finishing...
# Parsing tree 1497498
# Parsing subtree 1497498
# adding branch 1497498
# Finishing...
# Parsing tree 1489197
# Parsing subtree 1489197
# adding branch 1489197
# Finishing...
# Parsing tree 1502863
# Parsing subtree 1502863
# adding branch 1502863
# Finishing...
# Parsing tree 1512851
# Parsing subtree 1512851
# adding branch 1512851
# Finishing...
# Parsing tree 1506826
# Parsing subtree 1506826
# adding branch 1506826
# Finishing...
# Parsing tree 1505966
# Parsing subtree 1505966
# adding branch 1505966
# Finishing...
# Parsing tree 1509806
# Parsing subtree 1509806
# adding branch 1509806
# Finishing...
# Parsing tree 1512030
# Parsing subtree 1512030
# adding branch 1512030
# Finishing...
# Parsing tree 1505856
# Parsing subtree 1505856
# adding branch 1505856
# Finishing...
# Parsing tree 1512652
# Parsing subtree 1512652
# adding branch 1512652
# Finishing...
# Parsing tree 1511413
# Parsing subtree 1511413
# breaking
# adding branch 1511413
# Parsing subtree 1705806
# adding branch 1705806
# Parsing subtree 1705724
# adding branch 1705724
# Finishing...
# Parsing tree 1512560
# Parsing subtree 1512560
# adding branch 1512560
# Finishing...
# Parsing tree 1507197
# Parsing subtree 1507197
# adding branch 1507197
# Finishing...
# Parsing tree 1512570
# Parsing subtree 1512570
# breaking
# adding branch 1512570
# Parsing subtree 1593631
# breaking
# adding branch 1593631
# Parsing subtree 1666059
# adding branch 1666059
# Parsing subtree 1666060
# adding branch 1666060
# Parsing subtree 1593630
# adding branch 1593630
# Finishing...
# Parsing tree 1505519
# Parsing subtree 1505519
# adding branch 1505519
# Finishing...
# Parsing tree 1521152
# Parsing subtree 1521152
# adding branch 1521152
# Finishing...
# Parsing tree 1520525
# Parsing subtree 1520525
# adding branch 1520525
# Finishing...
# Parsing tree 1515247
# Parsing subtree 1515247
# adding branch 1515247
# Finishing...
# Parsing tree 1528140
# Parsing subtree 1528140
# adding branch 1528140
# Finishing...
# Parsing tree 1525361
# Parsing subtree 1525361
# adding branch 1525361
# Finishing...
# Parsing tree 1525617
# Parsing subtree 1525617
# breaking
# adding branch 1525617
# Parsing subtree 1670549
# adding branch 1670549
# Parsing subtree 1670568
# adding branch 1670568
# Finishing...
# Parsing tree 1522686
# Parsing subtree 1522686
# adding branch 1522686
# Finishing...
# Parsing tree 1522658
# Parsing subtree 1522658
# adding branch 1522658
# Finishing...
# Parsing tree 1536638
# Parsing subtree 1536638
# adding branch 1536638
# Finishing...
# Parsing tree 1535336
# Parsing subtree 1535336
# adding branch 1535336
# Finishing...
# Parsing tree 1558718
# Parsing subtree 1558718
# adding branch 1558718
# Finishing...
# Parsing tree 1561400
# Parsing subtree 1561400
# adding branch 1561400
# Finishing...
# Parsing tree 1548910
# Parsing subtree 1548910
# adding branch 1548910
# Finishing...
# Parsing tree 1556757
# Parsing subtree 1556757
# adding branch 1556757
# Finishing...
# Parsing tree 1546778
# Parsing subtree 1546778
# adding branch 1546778
# Finishing...
# Parsing tree 1556575
# Parsing subtree 1556575
# adding branch 1556575
# Finishing...
# Parsing tree 1557710
# Parsing subtree 1557710
# adding branch 1557710
# Finishing...
# Parsing tree 1551473
# Parsing subtree 1551473
# adding branch 1551473
# Finishing...
# Parsing tree 1538458
# Parsing subtree 1538458
# adding branch 1538458
# Finishing...
# Parsing tree 1544965
# Parsing subtree 1544965
# adding branch 1544965
# Finishing...
# Parsing tree 1543995
# Parsing subtree 1543995
# adding branch 1543995
# Finishing...
# Parsing tree 1543411
# Parsing subtree 1543411
# adding branch 1543411
# Finishing...
# Parsing tree 1541758
# Parsing subtree 1541758
# adding branch 1541758
# Finishing...
# Parsing tree 1538541
# Parsing subtree 1538541
# adding branch 1538541
# Finishing...
# Parsing tree 1564183
# Parsing subtree 1564183
# adding branch 1564183
# Finishing...
# Parsing tree 1567406
# Parsing subtree 1567406
# adding branch 1567406
# Finishing...
# Parsing tree 1563866
# Parsing subtree 1563866
# adding branch 1563866
# Finishing...
# Parsing tree 1567608
# Parsing subtree 1567608
# adding branch 1567608
# Finishing...
# Parsing tree 1571990
# Parsing subtree 1571990
# adding branch 1571990
# Finishing...
# Parsing tree 1583412
# Parsing subtree 1583412
# adding branch 1583412
# Finishing...
# Parsing tree 1581268
# Parsing subtree 1581268
# adding branch 1581268
# Finishing...
# Parsing tree 1576184
# Parsing subtree 1576184
# breaking
# adding branch 1576184
# Parsing subtree 1678183
# adding branch 1678183
# Parsing subtree 1678204
# adding branch 1678204
# Finishing...
# Parsing tree 1581818
# Parsing subtree 1581818
# adding branch 1581818
# Finishing...
# Parsing tree 1572383
# Parsing subtree 1572383
# adding branch 1572383
# Finishing...
# Parsing tree 1581588
# Parsing subtree 1581588
# adding branch 1581588
# Finishing...
# Parsing tree 1573385
# Parsing subtree 1573385
# adding branch 1573385
# Finishing...
# Parsing tree 1572361
# Parsing subtree 1572361
# adding branch 1572361
# Finishing...
# Parsing tree 1585576
# Parsing subtree 1585576
# adding branch 1585576
# Finishing...
# Parsing tree 1050392
# Parsing subtree 1050392
# adding branch 1050392
# Finishing...
# Parsing tree 1048377
# Parsing subtree 1048377
# adding branch 1048377
# Finishing...
# Parsing tree 1046064
# Parsing subtree 1046064
# adding branch 1046064
# Finishing...
# Parsing tree 1047998
# Parsing subtree 1047998
# adding branch 1047998
# Finishing...
# Parsing tree 1045706
# Parsing subtree 1045706
# adding branch 1045706
# Finishing...
# Parsing tree 1594653
# Parsing subtree 1594653
# adding branch 1594653
# Finishing...
# Parsing tree 1596165
# Parsing subtree 1596165
# adding branch 1596165
# Finishing...
# Parsing tree 1586178
# Parsing subtree 1586178
# adding branch 1586178
# Finishing...
# Parsing tree 1589509
# Parsing subtree 1589509
# adding branch 1589509
# Finishing...
# Parsing tree 1599653
# Parsing subtree 1599653
# adding branch 1599653
# Finishing...
# Parsing tree 1597791
# Parsing subtree 1597791
# adding branch 1597791
# Finishing...
# Parsing tree 1598673
# Parsing subtree 1598673
# adding branch 1598673
# Finishing...
# Parsing tree 1594455
# Parsing subtree 1594455
# adding branch 1594455
# Finishing...
# Parsing tree 1594445
# Parsing subtree 1594445
# adding branch 1594445
# Finishing...
# Parsing tree 1600463
# Parsing subtree 1600463
# adding branch 1600463
# Finishing...
# Parsing tree 1592588
# Parsing subtree 1592588
# adding branch 1592588
# Finishing...
# Parsing tree 1600749
# Parsing subtree 1600749
# breaking
# adding branch 1600749
# Parsing subtree 1665219
# adding branch 1665219
# Parsing subtree 1665220
# adding branch 1665220
# Finishing...
# Parsing tree 1593118
# Parsing subtree 1593118
# adding branch 1593118
# Finishing...
# Parsing tree 1592576
# Parsing subtree 1592576
# adding branch 1592576
# Finishing...
# Parsing tree 1592196
# Parsing subtree 1592196
# adding branch 1592196
# Finishing...
# Parsing tree 1606669
# Parsing subtree 1606669
# adding branch 1606669
# Finishing...
# Parsing tree 1608064
# Parsing subtree 1608064
# adding branch 1608064
# Finishing...
# Parsing tree 1604178
# Parsing subtree 1604178
# adding branch 1604178
# Finishing...
# Parsing tree 1607417
# Parsing subtree 1607417
# adding branch 1607417
# Finishing...
# Parsing tree 1607917
# Parsing subtree 1607917
# adding branch 1607917
# Finishing...
# Parsing tree 1625350
# Parsing subtree 1625350
# adding branch 1625350
# Finishing...
# Parsing tree 1619249
# Parsing subtree 1619249
# adding branch 1619249
# Finishing...
# Parsing tree 1618230
# Parsing subtree 1618230
# adding branch 1618230
# Finishing...
# Parsing tree 1623724
# Parsing subtree 1623724
# adding branch 1623724
# Finishing...
# Parsing tree 1618386
# Parsing subtree 1618386
# adding branch 1618386
# Finishing...
# Parsing tree 1610001
# Parsing subtree 1610001
# adding branch 1610001
# Finishing...
# Parsing tree 1617420
# Parsing subtree 1617420
# adding branch 1617420
# Finishing...
# Parsing tree 1611083
# Parsing subtree 1611083
# adding branch 1611083
# Finishing...
# Parsing tree 1614004
# Parsing subtree 1614004
# adding branch 1614004
# Finishing...
# Parsing tree 1610669
# Parsing subtree 1610669
# adding branch 1610669
# Finishing...
# Parsing tree 1615778
# Parsing subtree 1615778
# adding branch 1615778
# Finishing...
# Parsing tree 1610202
# Parsing subtree 1610202
# adding branch 1610202
# Finishing...
# Parsing tree 1629276
# Parsing subtree 1629276
# breaking
# adding branch 1629276
# Parsing subtree 1702587
# adding branch 1702587
# Parsing subtree 1702705
# adding branch 1702705
# Finishing...
# Parsing tree 1631358
# Parsing subtree 1631358
# adding branch 1631358
# Finishing...
# Parsing tree 1628158
# Parsing subtree 1628158
# adding branch 1628158
# Finishing...
# Parsing tree 1626867
# Parsing subtree 1626867
# adding branch 1626867
# Finishing...
# Parsing tree 1641473
# Parsing subtree 1641473
# adding branch 1641473
# Finishing...
# Parsing tree 1639977
# Parsing subtree 1639977
# adding branch 1639977
# Finishing...
# Parsing tree 1634921
# Parsing subtree 1634921
# adding branch 1634921
# Finishing...
# Parsing tree 1647876
# Parsing subtree 1647876
# adding branch 1647876
# Finishing...
# Parsing tree 1646905
# Parsing subtree 1646905
# adding branch 1646905
# Finishing...
# Parsing tree 1648232
# Parsing subtree 1648232
# adding branch 1648232
# Finishing...
# Parsing tree 1647490
# Parsing subtree 1647490
# adding branch 1647490
# Finishing...
# Parsing tree 1654088
# Parsing subtree 1654088
# adding branch 1654088
# Finishing...
# Parsing tree 1656952
# Parsing subtree 1656952
# adding branch 1656952
# Finishing...
# Parsing tree 1653612
# Parsing subtree 1653612
# adding branch 1653612
# Finishing...
# Parsing tree 1654430
# Parsing subtree 1654430
# adding branch 1654430
# Finishing...
# Parsing tree 1664539
# Parsing subtree 1664539
# adding branch 1664539
# Finishing...
# Parsing tree 1658670
# Parsing subtree 1658670
# adding branch 1658670
# Finishing...
# Parsing tree 1660040
# Parsing subtree 1660040
# adding branch 1660040
# Finishing...
# Parsing tree 1661657
# Parsing subtree 1661657
# adding branch 1661657
# Finishing...
# Parsing tree 1671760
# Parsing subtree 1671760
# adding branch 1671760
# Finishing...
# Parsing tree 1681212
# Parsing subtree 1681212
# adding branch 1681212
# Finishing...
# Parsing tree 1674956
# Parsing subtree 1674956
# adding branch 1674956
# Finishing...
# Parsing tree 1672625
# Parsing subtree 1672625
# adding branch 1672625
# Finishing...
# Parsing tree 1688472
# Parsing subtree 1688472
# adding branch 1688472
# Finishing...
# Parsing tree 1683958
# Parsing subtree 1683958
# adding branch 1683958
# Finishing...
# Parsing tree 1691224
# Parsing subtree 1691224
# adding branch 1691224
# Finishing...
# Parsing tree 1691772
# Parsing subtree 1691772
# adding branch 1691772
# Finishing...
# Parsing tree 1693841
# Parsing subtree 1693841
# adding branch 1693841
# Finishing...
# Parsing tree 1696896
# Parsing subtree 1696896
# adding branch 1696896
# Finishing...
# Parsing tree 1717008
# Parsing subtree 1717008
# adding branch 1717008
# Finishing...
# Parsing tree 1718027
# Parsing subtree 1718027
# adding branch 1718027
# Finishing...
# Parsing tree 1700241
# Parsing subtree 1700241
# adding branch 1700241
# Finishing...
# Parsing tree 1708005
# Parsing subtree 1708005
# adding branch 1708005
# Finishing...
# Parsing tree 1700663
# Parsing subtree 1700663
# adding branch 1700663
# Finishing...
# Parsing tree 1701826
# Parsing subtree 1701826
# adding branch 1701826
# Finishing...
# Parsing tree 1710231
# Parsing subtree 1710231
# adding branch 1710231
# Finishing...
# Parsing tree 1712651
# Parsing subtree 1712651
# adding branch 1712651
# Finishing...
# Parsing tree 1712268
# Parsing subtree 1712268
# adding branch 1712268
# Finishing...
# Parsing tree 1713702
# Parsing subtree 1713702
# adding branch 1713702
# Finishing...
# Parsing tree 1720949
# Parsing subtree 1720949
# adding branch 1720949
# Finishing...
# Parsing tree 1718121
# Parsing subtree 1718121
# adding branch 1718121
# Finishing...
# Parsing tree 1731584
# Parsing subtree 1731584
# adding branch 1731584
# Finishing...
# Parsing tree 1731387
# Parsing subtree 1731387
# adding branch 1731387
# Finishing...
# Parsing tree 1732318
# Parsing subtree 1732318
# adding branch 1732318
# Finishing...
# Parsing tree 1728585
# Parsing subtree 1728585
# adding branch 1728585
# Finishing...
# Parsing tree 1750931
# Parsing subtree 1750931
# adding branch 1750931
# Finishing...
# Parsing tree 1754887
# Parsing subtree 1754887
# adding branch 1754887
# Finishing...
# Parsing tree 1750588
# Parsing subtree 1750588
# adding branch 1750588
# Finishing...
# Parsing tree 1756122
# Parsing subtree 1756122
# adding branch 1756122
# Finishing...
# Parsing tree 1754459
# Parsing subtree 1754459
# adding branch 1754459
# Finishing...
# Parsing tree 1754563
# Parsing subtree 1754563
# adding branch 1754563
# Finishing...
# Parsing tree 1751876
# Parsing subtree 1751876
# adding branch 1751876
# Finishing...
# Parsing tree 1739029
# Parsing subtree 1739029
# adding branch 1739029
# Finishing...
# Parsing tree 1741060
# Parsing subtree 1741060
# adding branch 1741060
# Finishing...
# Parsing tree 1737020
# Parsing subtree 1737020
# adding branch 1737020
# Finishing...
# Parsing tree 1742798
# Parsing subtree 1742798
# adding branch 1742798
# Finishing...
# Parsing tree 1745512
# Parsing subtree 1745512
# adding branch 1745512
# Finishing...
# Parsing tree 1776025
# Parsing subtree 1776025
# adding branch 1776025
# Finishing...
# Parsing tree 1778396
# Parsing subtree 1778396
# adding branch 1778396
# Finishing...
# Parsing tree 1778813
# Parsing subtree 1778813
# adding branch 1778813
# Finishing...
# Parsing tree 1764803
# Parsing subtree 1764803
# adding branch 1764803
# Finishing...
# Parsing tree 1779306
# Parsing subtree 1779306
# adding branch 1779306
# Finishing...
# Parsing tree 1762216
# Parsing subtree 1762216
# adding branch 1762216
# Finishing...
# Parsing tree 1767341
# Parsing subtree 1767341
# adding branch 1767341
# Finishing...
# Parsing tree 1767238
# Parsing subtree 1767238
# adding branch 1767238
# Finishing...
# Parsing tree 1789470
# Parsing subtree 1789470
# adding branch 1789470
# Finishing...
# Parsing tree 1785376
# Parsing subtree 1785376
# adding branch 1785376
# Finishing...
# Parsing tree 1791690
# Parsing subtree 1791690
# adding branch 1791690
# Finishing...
# Parsing tree 1766937
# Parsing subtree 1766937
# adding branch 1766937
# Finishing...
# Parsing tree 1758820
# Parsing subtree 1758820
# adding branch 1758820
# Finishing...
# Parsing tree 1803775
# Parsing subtree 1803775
# adding branch 1803775
# Finishing...
# Parsing tree 1815567
# Parsing subtree 1815567
# adding branch 1815567
# Finishing...
# Parsing tree 1793049
# Parsing subtree 1793049
# adding branch 1793049
# Finishing...
# Parsing tree 1799709
# Parsing subtree 1799709
# adding branch 1799709
# Finishing...
# Parsing tree 1809610
# Parsing subtree 1809610
# adding branch 1809610
# Finishing...
# Parsing tree 1816423
# Parsing subtree 1816423
# adding branch 1816423
# Finishing...
# Parsing tree 1792405
# Parsing subtree 1792405
# adding branch 1792405
# Finishing...
# Parsing tree 1792613
# Parsing subtree 1792613
# adding branch 1792613
# Finishing...
# Parsing tree 1807724
# Parsing subtree 1807724
# adding branch 1807724
# Finishing...
# Parsing tree 1806306
# Parsing subtree 1806306
# adding branch 1806306
# Finishing...
# Parsing tree 1818382
# Parsing subtree 1818382
# adding branch 1818382
# Finishing...
# Parsing tree 1818677
# Parsing subtree 1818677
# adding branch 1818677
# Finishing...
# Parsing tree 1819340
# Parsing subtree 1819340
# adding branch 1819340
# Finishing...
# Parsing tree 1822194
# Parsing subtree 1822194
# adding branch 1822194
# Finishing...
# Parsing tree 1822305
# Parsing subtree 1822305
# adding branch 1822305
# Finishing...

# %%
svals = extract_values(tree, sits, ['POSITION_T', 'POSITION_X', 'POSITION_Y', 'TOTAL_INTENSITY', 'QUALITY'])
# Out:
# extracting values for 712363
# extracting values for 32772
# extracting values for 1153029
# extracting values for 601089
# extracting values for 1042443
# extracting values for 788492
# extracting values for 727054
# extracting values for 32784
# extracting values for 34833
# extracting values for 34834
# extracting values for 1607917
# extracting values for 739348
# extracting values for 1505966
# extracting values for 892954
# extracting values for 751643
# extracting values for 29360
# extracting values for 751651
# extracting values for 636593
# extracting values for 946217
# extracting values for 620586
# extracting values for 1316907
# extracting values for 880684
# extracting values for 985136
# extracting values for 893889
# extracting values for 1818677
# extracting values for 514104
# extracting values for 30779
# extracting values for 1226815
# extracting values for 1159232
# extracting values for 32835
# extracting values for 1392982
# extracting values for 915525
# extracting values for 608326
# extracting values for 716873
# extracting values for 1022029
# extracting values for 923729
# extracting values for 817166
# extracting values for 204893
# extracting values for 1556575
# extracting values for 30821
# extracting values for 30822
# extracting values for 32871
# extracting values for 751723
# extracting values for 1486956
# extracting values for 876653
# extracting values for 921712
# extracting values for 903283
# extracting values for 718964
# extracting values for 32887
# extracting values for 1656952
# extracting values for 1232916
# extracting values for 1691772
# extracting values for 1701826
# extracting values for 1187972
# extracting values for 751749
# extracting values for 1374342
# extracting values for 30857
# extracting values for 864394
# extracting values for 32907
# extracting values for 1712268
# extracting values for 829581
# extracting values for 32912
# extracting values for 30865
# extracting values for 751763
# extracting values for 518510
# extracting values for 948374
# extracting values for 784535
# extracting values for 57497
# extracting values for 34977
# extracting values for 98466
# extracting values for 721060
# extracting values for 1120421
# extracting values for 63655
# extracting values for 483497
# extracting values for 727751
# extracting values for 176301
# extracting values for 1472686
# extracting values for 656072
# extracting values for 1161396
# extracting values for 1789470
# extracting values for 29385
# extracting values for 1196220
# extracting values for 966845
# extracting values for 1558718
# extracting values for 1317056
# extracting values for 1007809
# extracting values for 1120451
# extracting values for 32969
# extracting values for 968180
# extracting values for 846030
# extracting values for 1822194
# extracting values for 977107
# extracting values for 1581268
# extracting values for 1641473
# extracting values for 1439962
# extracting values for 1093852
# extracting values for 760029
# extracting values for 53472
# extracting values for 88289
# extracting values for 1732318
# extracting values for 30076
# extracting values for 547051
# extracting values for 791250
# extracting values for 1505519
# extracting values for 756776
# extracting values for 760054
# extracting values for 760056
# extracting values for 397561
# extracting values for 798970
# extracting values for 30079
# extracting values for 760060
# extracting values for 760062
# extracting values for 1515247
# extracting values for 755969
# extracting values for 606466
# extracting values for 1507197
# extracting values for 1741060
# extracting values for 751877
# extracting values for 707288
# extracting values for 968981
# extracting values for 751897
# extracting values for 84250
# extracting values for 977180
# extracting values for 975139
# extracting values for 975144
# extracting values for 667945
# extracting values for 1000576
# extracting values for 995628
# extracting values for 1489197
# extracting values for 332081
# extracting values for 1335602
# extracting values for 1583412
# extracting values for 1538458
# extracting values for 1618230
# extracting values for 1646905
# extracting values for 1737020
# extracting values for 1057163
# extracting values for 1589509
# extracting values for 147782
# extracting values for 29001
# extracting values for 1061194
# extracting values for 768331
# extracting values for 31052
# extracting values for 1455501
# extracting values for 948561
# extracting values for 866644
# extracting values for 1374549
# extracting values for 770390
# extracting values for 921943
# extracting values for 760154
# extracting values for 86415
# extracting values for 1597791
# extracting values for 440672
# extracting values for 993636
# extracting values for 1354086
# extracting values for 29031
# extracting values for 1648232
# extracting values for 16750
# extracting values for 31723
# extracting values for 471410
# extracting values for 1512851
# extracting values for 1604178
# extracting values for 1528140
# extracting values for 708986
# extracting values for 1448316
# extracting values for 956798
# extracting values for 916885
# extracting values for 1608064
# extracting values for 772482
# extracting values for 1212805
# extracting values for 1042822
# extracting values for 323975
# extracting values for 108938
# extracting values for 840087
# extracting values for 194958
# extracting values for 758159
# extracting values for 815504
# extracting values for 108945
# extracting values for 477586
# extracting values for 764309
# extracting values for 977303
# extracting values for 1776025
# extracting values for 1370522
# extracting values for 969115
# extracting values for 1497498
# extracting values for 29093
# extracting values for 751345
# extracting values for 1585576
# extracting values for 1713702
# extracting values for 90866
# extracting values for 1509806
# extracting values for 61874
# extracting values for 29108
# extracting values for 63925
# extracting values for 803254
# extracting values for 33207
# extracting values for 784829
# extracting values for 375231
# extracting values for 1386944
# extracting values for 1450604
# extracting values for 1301238
# extracting values for 668103
# extracting values for 1331658
# extracting values for 1435948
# extracting values for 1210831
# extracting values for 977361
# extracting values for 969170
# extracting values for 29139
# extracting values for 1610202
# extracting values for 1322063
# extracting values for 1305062
# extracting values for 797159
# extracting values for 1538541
# extracting values for 997870
# extracting values for 33263
# extracting values for 607315
# extracting values for 313846
# extracting values for 1252777
# extracting values for 537080
# extracting values for 1348090
# extracting values for 1141244
# extracting values for 465408
# extracting values for 1819340
# extracting values for 119302
# extracting values for 58796
# extracting values for 1594455
# extracting values for 33294
# extracting values for 799247
# extracting values for 66067
# extracting values for 1581588
# extracting values for 80405
# extracting values for 975383
# extracting values for 307736
# extracting values for 1546778
# extracting values for 1104412
# extracting values for 107038
# extracting values for 1030687
# extracting values for 41508
# extracting values for 1377030
# extracting values for 576038
# extracting values for 1278503
# extracting values for 875048
# extracting values for 1629276
# extracting values for 1473066
# extracting values for 1276460
# extracting values for 1440305
# extracting values for 928308
# extracting values for 729654
# extracting values for 33335
# extracting values for 57912
# extracting values for 1286713
# extracting values for 449083
# extracting values for 754239
# extracting values for 971328
# extracting values for 472843
# extracting values for 29252
# extracting values for 948805
# extracting values for 734305
# extracting values for 1792405
# extracting values for 1003276
# extracting values for 143947
# extracting values for 1671760
# extracting values for 1004114
# extracting values for 1049171
# extracting values for 1818382
# extracting values for 754263
# extracting values for 776792
# extracting values for 1600463
# extracting values for 31322
# extracting values for 1512030
# extracting values for 1717008
# extracting values for 64101
# extracting values for 29286
# extracting values for 1313383
# extracting values for 1745512
# extracting values for 1634921
# extracting values for 29292
# extracting values for 1548910
# extracting values for 619123
# extracting values for 1720949
# extracting values for 928374
# extracting values for 29303
# extracting values for 1387128
# extracting values for 1262015
# extracting values for 762492
# extracting values for 898154
# extracting values for 1536638
# extracting values for 537218
# extracting values for 80517
# extracting values for 869652
# extracting values for 776839
# extracting values for 574093
# extracting values for 33427
# extracting values for 29335
# extracting values for 961176
# extracting values for 817817
# extracting values for 787101
# extracting values for 1200798
# extracting values for 1628158
# extracting values for 1317539
# extracting values for 963242
# extracting values for 33451
# extracting values for 1268396
# extracting values for 1280685
# extracting values for 907950
# extracting values for 752303
# extracting values for 1247920
# extracting values for 852657
# extracting values for 826036
# extracting values for 725685
# extracting values for 1485498
# extracting values for 29471
# extracting values for 211645
# extracting values for 1219266
# extracting values for 1036997
# extracting values for 1281825
# extracting values for 1229512
# extracting values for 408265
# extracting values for 64202
# extracting values for 32212
# extracting values for 64208
# extracting values for 1041105
# extracting values for 953042
# extracting values for 33495
# extracting values for 969432
# extracting values for 1661657
# extracting values for 1778396
# extracting values for 1512570
# extracting values for 460581
# extracting values for 1332347
# extracting values for 948967
# extracting values for 1372904
# extracting values for 172781
# extracting values for 1778813
# extracting values for 1477074
# extracting values for 1270514
# extracting values for 1626867
# extracting values for 90870
# extracting values for 1002964
# extracting values for 1581818
# extracting values for 836581
# extracting values for 74495
# extracting values for 1155841
# extracting values for 1544965
# extracting values for 310022
# extracting values for 64264
# extracting values for 1487627
# extracting values for 789261
# extracting values for 1754563
# extracting values for 80656
# extracting values for 1658670
# extracting values for 33558
# extracting values for 635673
# extracting values for 228126
# extracting values for 774943
# extracting values for 1178400
# extracting values for 879393
# extracting values for 772900
# extracting values for 29477
# extracting values for 881450
# extracting values for 758572
# extracting values for 764723
# extracting values for 1700663
# extracting values for 1561400
# extracting values for 1006393
# extracting values for 933343
# extracting values for 768829
# extracting values for 764735
# extracting values for 115520
# extracting values for 57483
# extracting values for 33604
# extracting values for 1338181
# extracting values for 889675
# extracting values for 1059661
# extracting values for 873297
# extracting values for 68434
# extracting values for 68435
# extracting values for 68437
# extracting values for 719702
# extracting values for 1048377
# extracting values for 60250
# extracting values for 1135451
# extracting values for 1470608
# extracting values for 1381179
# extracting values for 64356
# extracting values for 1693841
# extracting values for 33641
# extracting values for 1041258
# extracting values for 29159
# extracting values for 1653612
# extracting values for 1356657
# extracting values for 983922
# extracting values for 64371
# extracting values for 1332085
# extracting values for 33655
# extracting values for 1325944
# extracting values for 1611083
# extracting values for 859003
# extracting values for 996220
# extracting values for 1647490
# extracting values for 1592196
# extracting values for 752517
# extracting values for 764807
# extracting values for 33673
# extracting values for 91019
# extracting values for 1520525
# extracting values for 981902
# extracting values for 29586
# extracting values for 33603
# extracting values for 1463189
# extracting values for 1728585
# extracting values for 1688472
# extracting values for 29593
# extracting values for 535453
# extracting values for 31557
# extracting values for 766881
# extracting values for 1477541
# extracting values for 1480899
# extracting values for 1762216
# extracting values for 1344425
# extracting values for 1598673
# extracting values for 1610669
# extracting values for 1594445
# extracting values for 68527
# extracting values for 902067
# extracting values for 1004468
# extracting values for 1242037
# extracting values for 1203126
# extracting values for 29624
# extracting values for 1017332
# extracting values for 1073499
# extracting values for 1002430
# extracting values for 1301439
# extracting values for 961473
# extracting values for 31684
# extracting values for 1683958
# extracting values for 1029068
# extracting values for 1070499
# extracting values for 1061838
# extracting values for 844751
# extracting values for 99280
# extracting values for 33748
# extracting values for 1121238
# extracting values for 1417380
# extracting values for 1756122
# extracting values for 91983
# extracting values for 607198
# extracting values for 1599653
# extracting values for 1522658
# extracting values for 1182693
# extracting values for 31722
# extracting values for 1070059
# extracting values for 1209325
# extracting values for 1465326
# extracting values for 33777
# extracting values for 1401842
# extracting values for 69525
# extracting values for 220154
# extracting values for 1803775
# extracting values for 91132
# extracting values for 1522686
# extracting values for 1731584
# extracting values for 33793
# extracting values for 1586178
# extracting values for 1371307
# extracting values for 1072132
# extracting values for 1474662
# extracting values for 107692
# extracting values for 853003
# extracting values for 1606669
# extracting values for 64526
# extracting values for 1815567
# extracting values for 91154
# extracting values for 1793049
# extracting values for 1023011
# extracting values for 91172
# extracting values for 293928
# extracting values for 1131563
# extracting values for 1618386
# extracting values for 1573385
# extracting values for 1614004
# extracting values for 1068098
# extracting values for 881731
# extracting values for 216133
# extracting values for 1217606
# extracting values for 1617420
# extracting values for 826442
# extracting values for 1248333
# extracting values for 1764803
# extracting values for 771151
# extracting values for 1211475
# extracting values for 1006676
# extracting values for 1432761
# extracting values for 1338456
# extracting values for 543833
# extracting values for 433244
# extracting values for 1731387
# extracting values for 113758
# extracting values for 58465
# extracting values for 767078
# extracting values for 537706
# extracting values for 1816423
# extracting values for 1217987
# extracting values for 943214
# extracting values for 756847
# extracting values for 1512560
# extracting values for 1551473
# extracting values for 1135836
# extracting values for 33909
# extracting values for 33910
# extracting values for 759669
# extracting values for 1176698
# extracting values for 29819
# extracting values for 771196
# extracting values for 242538
# extracting values for 1631358
# extracting values for 951424
# extracting values for 1371267
# extracting values for 1660040
# extracting values for 967818
# extracting values for 33931
# extracting values for 1610001
# extracting values for 679059
# extracting values for 31892
# extracting values for 29845
# extracting values for 1571990
# extracting values for 1766937
# extracting values for 87196
# extracting values for 1664539
# extracting values for 1525617
# extracting values for 1248427
# extracting values for 937132
# extracting values for 1799709
# extracting values for 1465524
# extracting values for 811550
# extracting values for 1567406
# extracting values for 754872
# extracting values for 505017
# extracting values for 844987
# extracting values for 1809610
# extracting values for 1143999
# extracting values for 967872
# extracting values for 535745
# extracting values for 1739029
# extracting values for 1045706
# extracting values for 1512652
# extracting values for 1557710
# extracting values for 1567608
# extracting values for 31955
# extracting values for 91349
# extracting values for 1334488
# extracting values for 1563866
# extracting values for 452451
# extracting values for 363740
# extracting values for 914653
# extracting values for 1062110
# extracting values for 1398309
# extracting values for 1176801
# extracting values for 1139938
# extracting values for 91364
# extracting values for 1123557
# extracting values for 1008871
# extracting values for 1378855
# extracting values for 34029
# extracting values for 29935
# extracting values for 29936
# extracting values for 34344
# extracting values for 779507
# extracting values for 1033461
# extracting values for 1070326
# extracting values for 1576184
# extracting values for 1592576
# extracting values for 1647876
# extracting values for 836869
# extracting values for 1625350
# extracting values for 1718027
# extracting values for 81163
# extracting values for 1592588
# extracting values for 1477905
# extracting values for 92035
# extracting values for 902420
# extracting values for 249112
# extracting values for 1594653
# extracting values for 58656
# extracting values for 754977
# extracting values for 34085
# extracting values for 1296579
# extracting values for 29991
# extracting values for 1355996
# extracting values for 1164588
# extracting values for 1110237
# extracting values for 302384
# extracting values for 1619249
# extracting values for 91444
# extracting values for 1180981
# extracting values for 199992
# extracting values for 1424697
# extracting values for 894266
# extracting values for 34110
# extracting values for 772320
# extracting values for 32067
# extracting values for 1137991
# extracting values for 1654088
# extracting values for 673099
# extracting values for 27192
# extracting values for 531799
# extracting values for 1754459
# extracting values for 58716
# extracting values for 30049
# extracting values for 216977
# extracting values for 1535336
# extracting values for 531817
# extracting values for 32107
# extracting values for 1807724
# extracting values for 968049
# extracting values for 1596165
# extracting values for 395240
# extracting values for 245113
# extracting values for 1017212
# extracting values for 58750
# extracting values for 32127
# extracting values for 1505856
# extracting values for 1141778
# extracting values for 150925
# extracting values for 1600749
# extracting values for 91537
# extracting values for 32146
# extracting values for 990611
# extracting values for 34197
# extracting values for 980375
# extracting values for 34200
# extracting values for 759023
# extracting values for 982938
# extracting values for 85408
# extracting values for 945571
# extracting values for 271782
# extracting values for 1431793
# extracting values for 753065
# extracting values for 52652
# extracting values for 29597
# extracting values for 1672625
# extracting values for 1543411
# extracting values for 28085
# extracting values for 1111481
# extracting values for 794042
# extracting values for 1188767
# extracting values for 1047998
# extracting values for 62911
# extracting values for 638402
# extracting values for 1338819
# extracting values for 732612
# extracting values for 517574
# extracting values for 941512
# extracting values for 628170
# extracting values for 34251
# extracting values for 52684
# extracting values for 1681212
# extracting values for 40398
# extracting values for 925944
# extracting values for 251348
# extracting values for 85462
# extracting values for 1822305
# extracting values for 112091
# extracting values for 763359
# extracting values for 1091041
# extracting values for 58850
# extracting values for 1356027
# extracting values for 853476
# extracting values for 1367528
# extracting values for 976361
# extracting values for 1246699
# extracting values for 949740
# extracting values for 1436242
# extracting values for 1216524
# extracting values for 34288
# extracting values for 1386408
# extracting values for 818674
# extracting values for 751091
# extracting values for 790004
# extracting values for 966910
# extracting values for 764841
# extracting values for 106069
# extracting values for 1521152
# extracting values for 624129
# extracting values for 947714
# extracting values for 613891
# extracting values for 1572361
# extracting values for 1506826
# extracting values for 1357324
# extracting values for 790029
# extracting values for 137816
# extracting values for 753171
# extracting values for 1564183
# extracting values for 330596
# extracting values for 964123
# extracting values for 69148
# extracting values for 81437
# extracting values for 550430
# extracting values for 1572383
# extracting values for 1785376
# extracting values for 970672
# extracting values for 1457698
# extracting values for 859683
# extracting values for 613925
# extracting values for 413222
# extracting values for 763432
# extracting values for 1639977
# extracting values for 1696896
# extracting values for 32299
# extracting values for 63020
# extracting values for 58925
# extracting values for 1046064
# extracting values for 1056309
# extracting values for 91705
# extracting values for 1750588
# extracting values for 964157
# extracting values for 935492
# extracting values for 1214822
# extracting values for 32353
# extracting values for 34379
# extracting values for 34744
# extracting values for 958037
# extracting values for 1691224
# extracting values for 425566
# extracting values for 1792613
# extracting values for 374368
# extracting values for 517729
# extracting values for 1758820
# extracting values for 978535
# extracting values for 1257064
# extracting values for 1712651
# extracting values for 1779306
# extracting values for 790124
# extracting values for 1525361
# extracting values for 290418
# extracting values for 63092
# extracting values for 796277
# extracting values for 1105528
# extracting values for 32020
# extracting values for 63098
# extracting values for 1541758
# extracting values for 695935
# extracting values for 22144
# extracting values for 1556757
# extracting values for 32389
# extracting values for 757382
# extracting values for 763527
# extracting values for 1439368
# extracting values for 1036908
# extracting values for 1456987
# extracting values for 1442412
# extracting values for 783828
# extracting values for 966285
# extracting values for 401038
# extracting values for 1502863
# extracting values for 1700241
# extracting values for 1477912
# extracting values for 298645
# extracting values for 751633
# extracting values for 900760
# extracting values for 949916
# extracting values for 1654430
# extracting values for 593568
# extracting values for 1187489
# extracting values for 1316515
# extracting values for 1253028
# extracting values for 1440028
# extracting values for 34475
# extracting values for 1623724
# extracting values for 1425069
# extracting values for 34478
# extracting values for 818865
# extracting values for 1324727
# extracting values for 302776
# extracting values for 642801
# extracting values for 1412798
# extracting values for 873760
# extracting values for 34504
# extracting values for 1791690
# extracting values for 1674956
# extracting values for 1318611
# extracting values for 30422
# extracting values for 957391
# extracting values for 730845
# extracting values for 32478
# extracting values for 786147
# extracting values for 1201894
# extracting values for 500687
# extracting values for 513771
# extracting values for 724716
# extracting values for 758397
# extracting values for 1128177
# extracting values for 1710231
# extracting values for 34549
# extracting values for 1457449
# extracting values for 1607417
# extracting values for 263933
# extracting values for 816895
# extracting values for 886528
# extracting values for 759555
# extracting values for 759557
# extracting values for 243462
# extracting values for 1754887
# extracting values for 1406728
# extracting values for 1126153
# extracting values for 69387
# extracting values for 1361676
# extracting values for 1361677
# extracting values for 32526
# extracting values for 790290
# extracting values for 1400597
# extracting values for 1163031
# extracting values for 1050392
# extracting values for 759579
# extracting values for 1503005
# extracting values for 1593118
# extracting values for 967984
# extracting values for 32546
# extracting values for 765693
# extracting values for 33414
# extracting values for 1363755
# extracting values for 981559
# extracting values for 1027886
# extracting values for 1097519
# extracting values for 757553
# extracting values for 745267
# extracting values for 798516
# extracting values for 632629
# extracting values for 407353
# extracting values for 1543995
# extracting values for 872252
# extracting values for 34624
# extracting values for 1767238
# extracting values for 1324875
# extracting values for 931469
# extracting values for 1443665
# extracting values for 1195662
# extracting values for 757591
# extracting values for 751449
# extracting values for 1441444
# extracting values for 1419100
# extracting values for 769887
# extracting values for 38755
# extracting values for 30564
# extracting values for 32614
# extracting values for 759655
# extracting values for 1718121
# extracting values for 751473
# extracting values for 626546
# extracting values for 1064819
# extracting values for 769909
# extracting values for 32630
# extracting values for 30583
# extracting values for 918506
# extracting values for 69504
# extracting values for 982915
# extracting values for 1163345
# extracting values for 915337
# extracting values for 69514
# extracting values for 956303
# extracting values for 31384
# extracting values for 1750931
# extracting values for 145301
# extracting values for 1042330
# extracting values for 32667
# extracting values for 1615778
# extracting values for 1386822
# extracting values for 151463
# extracting values for 1157032
# extracting values for 34460
# extracting values for 573354
# extracting values for 907180
# extracting values for 1767341
# extracting values for 1232816
# extracting values for 1093555
# extracting values for 147384
# extracting values for 925452
# extracting values for 1147730
# extracting values for 34749
# extracting values for 1511413
# extracting values for 34754
# extracting values for 982347
# extracting values for 692164
# extracting values for 34757
# extracting values for 760140
# extracting values for 1386443
# extracting values for 149452
# extracting values for 1742798
# extracting values for 751567
# extracting values for 933841
# extracting values for 1082019
# extracting values for 1466325
# extracting values for 1071063
# extracting values for 1751876
# extracting values for 69284
# extracting values for 90079
# extracting values for 665568
# extracting values for 1476025
# extracting values for 1806306
# extracting values for 1708005
# extracting values for 1157688
# extracting values for 34792
# extracting values for 772073
# extracting values for 718826
# extracting values for 538603
# extracting values for 1007597
# extracting values for 1013745
# extracting values for 559093
# extracting values for 829433
# extracting values for 708602
# extracting values for 34811
# extracting values for 866301
# extracting values for 1206270

# %%
tree_id = list(tree.keys())[np.argmax([len(branch[x]) for x in tree.keys()])]
plot_tree_value(tree_id, "TOTAL_INTENSITY", svals)

# %% [markdown]
# ### II. Filter Trees

# %%
## WARNING: trees filtering by time affect other trees

# tree_filtered, branch_filtered, svals_filtered = filter_trees_by_time(tree, branch, svals)
tree, branch, svals = filter_trees_by_time(tree, branch, svals)

# %%
# ## TODO define as function

# # filter out trees starting later than T=10

# svals_filtered = {}

# for v in svals.keys():
#     svals_filtered[v] = {}

# for key in svals['POSITION_T'].keys():
    
#     # include trees with starting time T <= 10
#     if svals['POSITION_T'][key][key][0] <= 10:
#         for k in svals_filtered.keys():
#             svals_filtered[k][key] = svals[k][key]

# %% [markdown]
# ### III. Slit Asignment

# %%
path = '../test/eli-new-unsync-bf-%d/in-focus/before' % POSITION
impath = 'bf_in-focusxy%dc1c1-mask.tif' % POSITION
imorigpath = 'bf_in-focusxy%dc1c1.tif' % POSITION
immask = '../test/eli-new-unsync-bf-%d/out-focus/merged/merged.tif' % POSITION

im = cv2.imread(os.path.join(path, impath))
imorig = cv2.imread(os.path.join(path, imorigpath))
immask = cv2.imread(immask)

gray= cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
im2, contours, hierarchy  = cv2.findContours(gray,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)

# %%
cts, cts_size, cts_size_al = get_contour(os.path.join(path, impath))

# %%
pt.hist(cts_size, bins=20)
pt.title("Distribution of slit sizes (pixels)")
pt.xlabel("Slit size (pixels)")
pt.ylabel("# slits")
pt.show()

# %%
assocs, occuppancy = assign_tree_to_contours(svals, cts)

# %%
print("# of trees in slit: %d" % assocs[~assocs.SLIT_ID.isnull()].index.size)
print("Ratio  of cell lines not identified to specific slit: %f" % (assocs[assocs.SLIT_ID.isnull()].index.size / assocs.index.size))
print("ratio of slit not associated with any cell lineage: %f" % (occuppancy[occuppancy == 0].size / occuppancy.size))
# Out:
# # of trees in slit: 78
# Ratio  of cell lines not identified to specific slit: 0.297297
# ratio of slit not associated with any cell lineage: 0.778846

# %%
pt.hist(list(occuppancy))
pt.xticks(range(max(occuppancy) + 1))
pt.xlabel("Occupancy")
pt.ylabel("# Slits")
pt.title("Occupancy Histogram (all)")

# pt.gcf().set_size_inches(8, 5)

# %% [markdown]
# ### IV. Valid Trees Analysis

# %%
"""
Strategy:

I. For one division analysis
1. Find singly placed trees:
2. Do Cell Death Signal Filtering
3. Find tree with one division
4. Find tree with T(div) < t(treatment)
5. Find tree with T(death) > t(treatment)


in the new implementation the cells with no division are also valid
"""
# Out:
# '\nStrategy:\n\nI. For one division analysis\n1. Find singly placed trees:\n2. Do Cell Death Signal Filtering\n3. Find tree with one division\n4. Find tree with T(div) < t(treatment)\n5. Find tree with T(death) > t(treatment)\n\n\nin the new implementation the cells with no division are also valid\n'

# %%
"""
Collected statistics:
1. # singly-placed slits
2. # tree with zero div
3. # tree with one div
4. # tree with T(div) < t(treatment)
5. # tree with T(death) > t(treatment)
"""
# Out:
# '\nCollected statistics:\n1. # singly-placed slits\n2. # tree with zero div\n3. # tree with one div\n4. # tree with T(div) < t(treatment)\n5. # tree with T(death) > t(treatment)\n'

# %%
# dev pipeline
doubly_placed_tree = get_trees_by_placement(assocs, placement=2)
print("# of doubly-placed trees: %d" % len(doubly_placed_tree))

singly_placed_tree = get_trees_by_placement(assocs, placement=1)
print("# of singly-placed trees: %d" % len(singly_placed_tree))
# Out:
# # of doubly-placed trees: 7
# # of singly-placed trees: 61

# %% [markdown]
# ### V. Embed Signal Information Into Data

# %%
tree_unpruned = copy.deepcopy(tree)
branch_unpruned = copy.deepcopy(branch)
svals_unpruned = copy.deepcopy(svals)

for t in (singly_placed_tree + doubly_placed_tree):
    t_tree, t_branch, _, this_svals = embed_cell_death_signal(t, tree, branch, svals, caspase_tiff_path)
    tree[t] = t_tree
    branch[t] = t_branch
    svals = this_svals
# Out:
# processing tree 33793
#   processing branch 33793
#   processing branch 176508
#   processing branch 176502
#   processing branch 535651
#   processing branch 535614
#   processing branch 571286
#   processing branch 612626
#   processing branch 612627
#   processing branch 746190
#   processing branch 746175
#   processing branch 763573
#   processing branch 1105791
#   processing branch 1105735
#   processing branch 763558
#   processing branch 571305
# processing tree 33451
#   processing branch 33451
#     branch 33451 marked dead
#     shortening {tree, brightness, measurement values} of 33451 at position 252 (exclusive)
# processing tree 32772
#   processing branch 32772
#   processing branch 79258
#   processing branch 440260
#   processing branch 440222
#   processing branch 79303
# processing tree 33294
#   processing branch 33294
#   processing branch 130618
#   processing branch 136210
#   processing branch 273075
#   processing branch 273081
#   processing branch 336395
#   processing branch 470369
#   processing branch 565036
#   processing branch 564998
#   processing branch 776470
#   processing branch 1048791
#   processing branch 1048846
#   processing branch 776497
#   processing branch 470358
#   processing branch 336394
#   processing branch 136201
#   processing branch 130592
# processing tree 32784
#   processing branch 32784
#   processing branch 181360
#   processing branch 255247
#   processing branch 255301
#   processing branch 382102
#   processing branch 382140
#   processing branch 487361
#   processing branch 546642
#   processing branch 546589
#   processing branch 600119
#   processing branch 623420
#   processing branch 623458
#   processing branch 600077
#   processing branch 487318
#   processing branch 181372
# processing tree 32020
#   processing branch 32020
#   processing branch 761728
#   processing branch 761779
# processing tree 33558
#   processing branch 33558
#   processing branch 435026
#     branch 435026 marked dead
#     shortening {tree, brightness, measurement values} of 435026 at position 167 (exclusive)
#   processing branch 435064
# processing tree 32871
#   processing branch 32871
# processing tree 29471
#   processing branch 29471
# processing tree 34085
#   processing branch 34085
#   processing branch 535879
#   processing branch 734443
#   processing branch 734521
#   processing branch 535926
# processing tree 29991
#   processing branch 29991
# processing tree 32299
#   processing branch 32299
#   processing branch 346969
#     branch 346969 marked dead
#     shortening {tree, brightness, measurement values} of 346969 at position 181 (exclusive)
#   processing branch 346918
# processing tree 30857
#   processing branch 30857
#   processing branch 111090
#   processing branch 190879
#   processing branch 190852
#   processing branch 111089
# processing tree 30779
#   processing branch 30779
# processing tree 34110
#   processing branch 34110
# processing tree 29252
#   processing branch 29252
#   processing branch 138097
#   processing branch 138116
#   processing branch 625825
#   processing branch 625824
#   processing branch 702929
#   processing branch 702935
#   processing branch 820035
#   processing branch 819991
# processing tree 31557
#   processing branch 31557
# processing tree 32353
#   processing branch 32353
#   processing branch 823690
#   processing branch 823683
# processing tree 31052
#   processing branch 31052
#   processing branch 704525
#   processing branch 704506
#   processing branch 896296
#   processing branch 896070
#   processing branch 1153091
#   processing branch 1212598
#   processing branch 1212521
#   processing branch 1153200
# processing tree 32526
#   processing branch 32526
#   processing branch 516762
#   processing branch 676569
#   processing branch 676579
#   processing branch 1082620
#   processing branch 1082524
#   processing branch 516761
# processing tree 31322
#   processing branch 31322
#   processing branch 450310
#   processing branch 450366
# processing tree 30049
#   processing branch 30049
# processing tree 30564
#   processing branch 30564
#     branch 30564 marked dead
#     shortening {tree, brightness, measurement values} of 30564 at position 253 (exclusive)
# processing tree 30821
#   processing branch 30821
# processing tree 30822
#   processing branch 30822
#   processing branch 743697
#   processing branch 1039211
#   processing branch 1039181
#   processing branch 743661
# processing tree 33641
#   processing branch 33641
# processing tree 32107
#   processing branch 32107
# processing tree 33655
#   processing branch 33655
#   processing branch 511741
#   processing branch 511725
# processing tree 29819
#   processing branch 29819
#   processing branch 567448
#   processing branch 591318
#   processing branch 602869
#   processing branch 691368
#   processing branch 691302
#   processing branch 742009
#   processing branch 741900
#   processing branch 602938
#   processing branch 591330
#   processing branch 567505
# processing tree 30076
#   processing branch 30076
# processing tree 34197
#   processing branch 34197
# processing tree 32389
#   processing branch 32389
# processing tree 33414
#   processing branch 33414
#   processing branch 399978
#   processing branch 400042
#     branch 400042 marked dead
#     shortening {tree, brightness, measurement values} of 400042 at position 181 (exclusive)
# processing tree 33673
#   processing branch 33673
#   processing branch 701095
#   processing branch 701086
#   processing branch 1062913
#   processing branch 1230352
#   processing branch 1283644
#   processing branch 1283683
#   processing branch 1230320
#   processing branch 1062940
# processing tree 32907
#   processing branch 32907
# processing tree 30865
#   processing branch 30865
# processing tree 32146
#   processing branch 32146
# processing tree 32067
#   processing branch 32067
#   processing branch 474919
#   processing branch 474973
#   processing branch 723445
#   processing branch 723446
#   processing branch 925346
#   processing branch 925329
# processing tree 31892
#   processing branch 31892
#   processing branch 317943
#   processing branch 317836
# processing tree 29845
#   processing branch 29845
# processing tree 29335
#   processing branch 29335
# processing tree 34200
#   processing branch 34200
# processing tree 29593
#   processing branch 29593
#   processing branch 195338
#   processing branch 195339
# processing tree 32969
#   processing branch 32969
#   processing branch 647376
#   processing branch 676951
#   processing branch 676952
#   processing branch 647431
# processing tree 33263
#   processing branch 33263
#   processing branch 481808
#   processing branch 481819
# processing tree 29597
#   processing branch 29597
# processing tree 31384
#   processing branch 31384
# processing tree 29108
#   processing branch 29108
#   processing branch 472185
#   processing branch 472158
# processing tree 33207
#   processing branch 33207
# processing tree 34251
#   processing branch 34251
#   processing branch 356931
#   processing branch 357024
#   processing branch 784311
#   processing branch 784297
#   processing branch 870187
#   processing branch 870067
# processing tree 31684
#   processing branch 31684
# processing tree 29385
#   processing branch 29385
#   processing branch 234541
#   processing branch 234495
# processing tree 29303
#   processing branch 29303
#   processing branch 138143
#   processing branch 138144
# processing tree 30422
#   processing branch 30422
#   processing branch 362196
#   processing branch 520448
#   processing branch 520410
#   processing branch 875607
#   processing branch 875644
#   processing branch 362182
# processing tree 33495
#   processing branch 33495
# processing tree 32478
#   processing branch 32478
#   processing branch 688194
#   processing branch 755315
#     branch 755315 marked dead
#     shortening {tree, brightness, measurement values} of 755315 at position 84 (exclusive)
#   processing branch 755314
#   processing branch 688180
# processing tree 29159
#   processing branch 29159
#   processing branch 109620
#   processing branch 109584
#   processing branch 702886
#   processing branch 702847
#   processing branch 1017261
#   processing branch 1017239
# processing tree 34029
#   processing branch 34029
#   processing branch 547814
#   processing branch 913871
#   processing branch 913870
#   processing branch 547779
# processing tree 32212
#   processing branch 32212
# processing tree 32127
#   processing branch 32127
#   processing branch 364063
#   processing branch 364037
#   processing branch 593589
#   processing branch 593647
#   processing branch 646650
#   processing branch 646623
# processing tree 30079
#   processing branch 30079
#   processing branch 531885
#   processing branch 531921
# processing tree 33604
#   processing branch 33604
#   processing branch 1314350
#   processing branch 1376436
#   processing branch 1376391
#   processing branch 1447338
#   processing branch 1447261
#   processing branch 1314413
# processing tree 32546
#   processing branch 32546
# processing tree 33909
#   processing branch 33909
# processing tree 29093
#   processing branch 29093
# processing tree 34478
#   processing branch 34478
# processing tree 31722
#   processing branch 31722
# processing tree 29935
#   processing branch 29935
#   processing branch 23604
#   processing branch 23695

# %% [markdown]
# ###  VI. Iterative filtering of valid trees

# %%
# dev func

def filter_invalid_trees(singly_placed_trees, tree, branch, tree_values):

    # calculate number of divs for each tree
    singly_placed_tree_div = []
    for t in singly_placed_tree:
        ### return: tree-division
        singly_placed_tree_div.append(len(tree_values['POSITION_T'][t].keys()))

    ## filter out trees having other than one division
    
    # trees with one division event
    ### return: no div tree
    invalid_tree_nodiv = list(np.array(singly_placed_tree)[np.array(singly_placed_tree_div) == 1])
    ### return: more one div tree
    invalid_tree_morethan1div = list(np.array(singly_placed_tree)[np.array(singly_placed_tree_div) > 3])
    ### return: one div tree
    tree_one_div = list(np.array(singly_placed_tree)[np.array(singly_placed_tree_div) == 3])

    print("# of singly-placed trees with 0 div: %d" % len(invalid_tree_nodiv))
    print("# of singly-placed trees with 1 div: %d" % len(tree_one_div))
    print("# of singly-placed trees with >1 divs: %d" % len(invalid_tree_morethan1div))

    ## compute div times
    
    ### return: division times of one div tree
    tree_one_div_div_times = compute_first_division_time_list(tree_one_div, tree, branch, tree_values, mode='avg')

    ## filter out trees with division after treatment

    valid = np.array(tree_one_div_div_times) < (126 * TIME_UNIT_FACTOR)
    
    invalid_tree_divaftertreatment = list(np.array(tree_one_div)[~valid])
    ### return: div before treatment tree
    tree_divbfrtreatment = list(np.array(tree_one_div)[valid])
    ### return: division times of div before treatment tree
    tree_divbfrtreatment_div_times = list(np.array(tree_one_div_div_times)[valid])

    print("# trees with division time before treatment: %d" % len(tree_divbfrtreatment))
    
    ## filter out trees with child's death before treatment

    # compute the death time of both child branches
    death_times_1 = []
    death_times_2 = []

    for t in tree_divbfrtreatment:
        t_time = svals['POSITION_T'][t]
        t_tree = tree[t]
        t_branch = branch[t]
    
        last_time_1 = t_time[t_branch[t][0]][-1]
        last_time_2 = t_time[t_branch[t][1]][-1]
    
        death_times_1.append(last_time_1)
        death_times_2.append(last_time_2)

    valid1 = np.array(death_times_1) > (126 * TIME_UNIT_FACTOR)
    valid2 = np.array(death_times_2) > (126 * TIME_UNIT_FACTOR)
    valid = valid1 & valid2
    
    tree_divbfrtreatment_last_time_1 = death_times_1
    tree_divbfrtreatment_last_time_2 = death_times_2

    invalid_tree_deathbeforetreatment = list(np.array(tree_divbfrtreatment)[~valid])
    ## return: death after treatment tree
    tree_deathaftertreatment = list(np.array(tree_divbfrtreatment)[valid])
    ## return: death time of 1st child
    last_time_1 = list(np.array(death_times_1)[valid])
    ## return: death time of 2nd child
    last_time_2 = list(np.array(death_times_2)[valid])
    ## return:  division times of death after treatment tree
    tree_deathaftertreatment_div_times = list(np.array(tree_divbfrtreatment_div_times)[valid])
    print("# trees with both branches' last measurement time after treatment: %d" % len(tree_deathaftertreatment))
    
    return singly_placed_tree_div, \
            invalid_tree_nodiv, \
            invalid_tree_morethan1div, \
            tree_one_div, \
            tree_one_div_div_times, \
            tree_divbfrtreatment, \
            tree_divbfrtreatment_div_times, \
            tree_divbfrtreatment_last_time_1, \
            tree_divbfrtreatment_last_time_2, \
            tree_deathaftertreatment, \
            tree_deathaftertreatment_div_times, \
            last_time_1, \
            last_time_2

# %%
singly_placed_tree_divs, \
    invalid_trees_nodiv, \
    invalid_trees_morethan1div, \
    tree_one_div, \
    tree_one_div_div_times, \
    tree_divbfrtreatment, \
    tree_divbfrtreatment_div_times, \
    tree_divbfrtreatment_last_time_1, \
    tree_divbfrtreatment_last_time_2, \
    tree_deathaftertreatment, \
    tree_deathaftertreatment_div_times, \
    last_time_1, \
    last_time_2 = filter_invalid_trees(singly_placed_tree, tree, branch, svals)
# Out:
# # of singly-placed trees with 0 div: 27
# # of singly-placed trees with 1 div: 14
# # of singly-placed trees with >1 divs: 20
# # trees with division time before treatment: 12
# # trees with both branches' last measurement time after treatment: 8

# %%
# end of dev func

# %%
# end of dev pipeline

# %%
## TODO: delete

# # DELETE afer dev
# # find valid trees (singly placed trees)
# valid_trees = []
# invalid_trees_doubly_placed = []
# for slit in assocs.SLIT_ID.unique():
#     if assocs[assocs.SLIT_ID == slit].index.size == 1:
#         ## return: singly-placed tree
#         valid_trees.append(assocs[assocs.SLIT_ID == slit]['CELL_LINE'].values[0])
#     elif assocs[assocs.SLIT_ID == slit].index.size == 2:
#         ## return: doubly-placed tree
#         invalid_trees_doubly_placed.append(assocs[assocs.SLIT_ID == slit]['CELL_LINE'].values[0])
        
# print("# of singly-placed trees: %d" % len(valid_trees))

# # calculate number of divs for each tree
# valid_trees_divs = []
# for t in valid_trees:
#     ## return: tree-division
#     valid_trees_divs.append(len(svals['POSITION_T'][t].keys()))

# # trees with one division event
# ## return
# invalid_trees_nodiv = list(np.array(valid_trees)[np.array(valid_trees_divs) == 1])
# ## return
# invalid_trees_morethan1div = list(np.array(valid_trees)[np.array(valid_trees_divs) > 3])
# valid_trees = list(np.array(valid_trees)[np.array(valid_trees_divs) == 3])

# print("# of singly-placed trees with 1 div: %d" % len(valid_trees))

# # filter out trees with division after treatment

# valid = np.array(div_times) < (126 * TIME_UNIT_FACTOR)
# ## return
# invalid_trees_divaftertreatment = list(np.array(valid_trees)[~valid])
# valid_trees = list(np.array(valid_trees)[valid])
# ## return
# div_times = list(np.array(div_times)[valid])

# print("# trees with division time after treatment: %d" % len(div_times))

# death_times_1 = []
# death_times_2 = []

# for t in valid_trees:
#     t_time = svals['POSITION_T'][t]
#     t_tree = tree[t]
#     t_branch = branch[t]
    
#     last_time_1 = t_time[t_branch[t][0]][-1]
#     last_time_2 = t_time[t_branch[t][1]][-1]
    
#     death_times_1.append(last_time_1)
#     death_times_2.append(last_time_2)
    
# valid1 = np.array(death_times_1) > (126 * TIME_UNIT_FACTOR)
# valid2 = np.array(death_times_2) > (126 * TIME_UNIT_FACTOR)
# valid = valid1 & valid2

# invalid_trees_deathbeforetreatment = list(np.array(valid_trees)[~valid])
# valid_trees = list(np.array(valid_trees)[valid])
# last_time_1 = list(np.array(death_times_1)[valid])
# last_time_2 = list(np.array(death_times_2)[valid])
# div_times = list(np.array(div_times)[valid])
# print("# trees with both branches' last measurement time after treatment: %d" % len(div_times))

# %%
## TODO: delete

# # find valid trees (singly placed trees)
# valid_trees = []
# invalid_trees_doubly_placed = []
# for slit in assocs.SLIT_ID.unique():
#     if assocs[assocs.SLIT_ID == slit].index.size == 1:
#         valid_trees.append(assocs[assocs.SLIT_ID == slit]['CELL_LINE'].values[0])
#     elif assocs[assocs.SLIT_ID == slit].index.size == 2:
#         invalid_trees_doubly_placed.append(assocs[assocs.SLIT_ID == slit]['CELL_LINE'].values[0])
        
# print("# of singly-placed trees: %d" % len(valid_trees))

# # calculate number of divs for each tree
# valid_trees_divs = []
# for t in valid_trees:
#     valid_trees_divs.append(len(svals['POSITION_T'][t].keys()))

# # trees with one division event
# invalid_trees_nodiv = list(np.array(valid_trees)[np.array(valid_trees_divs) == 1])
# invalid_trees_morethan1div = list(np.array(valid_trees)[np.array(valid_trees_divs) > 3])
# valid_trees = list(np.array(valid_trees)[np.array(valid_trees_divs) == 3])

# print("# of singly-placed trees with 1 div: %d" % len(valid_trees))

# %%
# plot number of divisions of valid trees

## CHANGED

pt.hist(singly_placed_tree_divs, bins=max(singly_placed_tree_divs))
pt.title("Histogram of branch numbers per cell tree")
pt.ylabel("# Cell trees")
pt.xlabel("# Branches")

# %%
## TODO: delete

# div_times = compute_first_division_time_list(valid_trees, tree, branch, svals, mode='avg')

# %%
## CHANGED

pt.hist(tree_one_div_div_times)
pt.title("Distribution of tree's division times")
pt.xlabel("Division time")
pt.axvline(126 * TIME_UNIT_FACTOR, c='red')
pt.gcf().set_size_inches(10, 6)

# %%
## TODO: delete

# filter out trees with division after treatment

# valid = np.array(div_times) < (126 * TIME_UNIT_FACTOR)
# invalid_trees_divaftertreatment = list(np.array(valid_trees)[~valid])
# valid_trees = list(np.array(valid_trees)[valid])
# div_times = list(np.array(div_times)[valid])

# print("# trees with division time after treatment: %d" % len(div_times))

# %%
# death_times_1 = []
# death_times_2 = []

# for t in valid_trees:
#     t_time = svals['POSITION_T'][t]
#     t_tree = tree[t]
#     t_branch = branch[t]
    
#     last_time_1 = t_time[t_branch[t][0]][-1]
#     last_time_2 = t_time[t_branch[t][1]][-1]
    
#     death_times_1.append(last_time_1)
#     death_times_2.append(last_time_2)

# %%
## CHANGED

pt.hist(tree_divbfrtreatment_last_time_1 + tree_divbfrtreatment_last_time_2)
pt.title("Distribution of tree branch's last measurement time")
pt.xlabel("Branch's last measurement time")
pt.axvline(126 * TIME_UNIT_FACTOR, c='red')
pt.gcf().set_size_inches(10, 6)

# %%
## CHANGED

high = int(max(tree_divbfrtreatment_div_times + tree_divbfrtreatment_last_time_1 + tree_divbfrtreatment_last_time_2))
pt.scatter(tree_divbfrtreatment_div_times, tree_divbfrtreatment_last_time_1)
pt.scatter(tree_divbfrtreatment_div_times, tree_divbfrtreatment_last_time_2)
pt.plot(list(range(high)), list(range(high)))

pt.title("Scatter plot of division time vs branch's last measurement time")
pt.xlabel("Tree's division time")
pt.ylabel("Branch's last measurement time")
pt.axhline(126 * TIME_UNIT_FACTOR, c='red')
pt.gcf().set_size_inches(10, 10)

# %%
## TODO: delete

# valid1 = np.array(death_times_1) > (126 * TIME_UNIT_FACTOR)
# valid2 = np.array(death_times_2) > (126 * TIME_UNIT_FACTOR)
# valid = valid1 & valid2

# %%
## TODO: delete

# invalid_trees_deathbeforetreatment = list(np.array(valid_trees)[~valid])
# valid_trees = list(np.array(valid_trees)[valid])
# last_time_1 = list(np.array(death_times_1)[valid])
# last_time_2 = list(np.array(death_times_2)[valid])
# div_times = list(np.array(div_times)[valid])
# print("# trees with both branches' last measurement time after treatment: %d" % len(div_times))

# %%
## CHANGED

tree_deathaftertreatment
# Out:
# [33558, 32299, 31322, 33414, 29593, 33263, 29385, 30079]

# %%
## CHANGED

ttd1 = [(x - 126 * TIME_UNIT_FACTOR) for x in last_time_1]
ttd2 = [(x - 126 * TIME_UNIT_FACTOR) for x in last_time_2]

# %%
## CHANGED

pt.scatter(tree_deathaftertreatment_div_times, ttd1)
pt.scatter(tree_deathaftertreatment_div_times, ttd2)
pt.title("Scatter plot of division time vs Time-to-death")
pt.xlabel("Division time")
pt.ylabel("Time to death")
pt.gcf().set_size_inches(10, 10)

# %% [markdown]
# ### V. Export Tree Data

# %%
write_time_to_death_statistics(exit_dat, tree_deathaftertreatment, tree_deathaftertreatment_div_times, ttd1, ttd2)

# %% [markdown]
# ### VI. Export TIFFs

# %%
## draw contours with $num cell lineages

num = 0

ctsprint = [cts[x] for x in list(np.argwhere(occuppancy == num).T[[0]][0])]

imc = imorig.copy()
cv2.drawContours(imc, ctsprint, -1, (255, 0, 0), 4)
cv2.imwrite(os.path.join(path, 'im_contours_%d.tiff' % num), imc);

imc = immask.copy()
cv2.drawContours(imc, ctsprint, -1, (255, 0, 0), 4)
cv2.imwrite(os.path.join(path, 'im_contours_%d_mask.tiff' % num), imc);

# %%
## draw all spots in T=0

imc = imorig.copy()
for sid in ss[ss.POSITION_T == 0]['ID']:
    x = ss[ss.ID == sid]['POSITION_X'].values[0] / PIXEL_INCH_RATIO
    y = ss[ss.ID == sid]['POSITION_Y'].values[0] / PIXEL_INCH_RATIO
    cv2.circle(imc, (int(x) + 3, int(y) + 3),4, (255, 255, 0), -1)
cv2.imwrite(os.path.join(path, 'all_t0.tiff'), imc);

# %%
## draw contours with $num cell lineages

num = 1

ctsprint = [cts[x] for x in list(np.argwhere(occuppancy == num).T[[0]][0])]

imc = imorig.copy()
cv2.drawContours(imc, ctsprint, -1, (255, 0, 0), 4)
for tr in list(np.argwhere(occuppancy == num).T[[0]][0]):
    pths = assocs[assocs.SLIT_ID == tr].CELL_LINE.tolist()
    for pth in pths:
        y = svals['POSITION_Y'][pth][pth][0] / PIXEL_INCH_RATIO
        x = svals['POSITION_X'][pth][pth][0] / PIXEL_INCH_RATIO
        cv2.circle(imc, (int(x), int(y)), 4, (0, 255, 0), -1)
#         cv2.putText(imc,"track %d: coord (%d, %d)" % (pth, int(x), int(y)), 
#                     (int(x), int(y)), cv2.FONT_HERSHEY_COMPLEX, 0.8,(255,255,255),2,cv2.LINE_AA)
cv2.imwrite(os.path.join(path, 'im_contours_%d.tiff' % num), imc);

imc = immask.copy()
cv2.drawContours(imc, ctsprint, -1, (255, 0, 0), 4)
for tr in list(np.argwhere(occuppancy == num).T[[0]][0]):
    pths = assocs[assocs.SLIT_ID == tr].CELL_LINE.tolist()
    for pth in pths:
        y = svals['POSITION_Y'][pth][pth][0] / PIXEL_INCH_RATIO
        x = svals['POSITION_X'][pth][pth][0] / PIXEL_INCH_RATIO
        cv2.circle(imc, (int(x), int(y)), 4, (0, 255, 0), -1)
#         cv2.putText(imc,"track %d: coord (%d, %d)" % (pth, int(x), int(y)), 
#                     (int(x), int(y)), cv2.FONT_HERSHEY_COMPLEX, 0.8,(255,255,255),2,cv2.LINE_AA)
cv2.imwrite(os.path.join(path, 'im_contours_%d_mask.tiff' % num), imc);

# %%
## draw contours with $num cell lineages

num = 2

ctsprint = [cts[x] for x in list(np.argwhere(occuppancy == num).T[[0]][0])]

imc = imorig.copy()
cv2.drawContours(imc, ctsprint, -1, (255, 0, 0), 4)
for tr in list(np.argwhere(occuppancy == num).T[[0]][0]):
    pths = assocs[assocs.SLIT_ID == tr].CELL_LINE.tolist()
    for pth in pths:
        y = svals['POSITION_Y'][pth][pth][0] / PIXEL_INCH_RATIO
        x = svals['POSITION_X'][pth][pth][0] / PIXEL_INCH_RATIO
        cv2.circle(imc, (int(x), int(y)), 4, (0, 255, 0), -1)
#         cv2.putText(imc,"track %d: coord (%d, %d)" % (pth, int(x), int(y)), 
#                     (int(x), int(y)), cv2.FONT_HERSHEY_COMPLEX, 0.8,(255,255,255),2,cv2.LINE_AA)
cv2.imwrite(os.path.join(path, 'im_contours_%d.tiff' % num), imc);

imc = immask.copy()
cv2.drawContours(imc, ctsprint, -1, (255, 0, 0), 4)
for tr in list(np.argwhere(occuppancy == num).T[[0]][0]):
    pths = assocs[assocs.SLIT_ID == tr].CELL_LINE.tolist()
    for pth in pths:
        y = svals['POSITION_Y'][pth][pth][0] / PIXEL_INCH_RATIO
        x = svals['POSITION_X'][pth][pth][0] / PIXEL_INCH_RATIO
        cv2.circle(imc, (int(x), int(y)), 4, (0, 255, 0), -1)
#         cv2.putText(imc,"track %d: coord (%d, %d)" % (pth, int(x), int(y)), 
#                     (int(x), int(y)), cv2.FONT_HERSHEY_COMPLEX, 0.8,(255,255,255),2,cv2.LINE_AA)
cv2.imwrite(os.path.join(path, 'im_contours_%d_mask.tiff' % num), imc);

# %%
## draw contours with $num cell lineages

num = 3

ctsprint = [cts[x] for x in list(np.argwhere(occuppancy == num).T[[0]][0])]

imc = imorig.copy()
cv2.drawContours(imc, ctsprint, -1, (255, 0, 0), 4)
for tr in list(np.argwhere(occuppancy == num).T[[0]][0]):
    pths = assocs[assocs.SLIT_ID == tr].CELL_LINE.tolist()
    for pth in pths:
        y = svals['POSITION_Y'][pth][pth][0] / PIXEL_INCH_RATIO
        x = svals['POSITION_X'][pth][pth][0] / PIXEL_INCH_RATIO
        cv2.circle(imc, (int(x), int(y)), 4, (0, 255, 0), -1)
#         cv2.putText(imc,"track %d: coord (%d, %d)" % (pth, int(x), int(y)), 
#                     (int(x), int(y)), cv2.FONT_HERSHEY_COMPLEX, 0.8,(255,255,255),2,cv2.LINE_AA)
cv2.imwrite(os.path.join(path, 'im_contours_%d.tiff' % num), imc);

imc = immask.copy()
cv2.drawContours(imc, ctsprint, -1, (255, 0, 0), 4)
for tr in list(np.argwhere(occuppancy == num).T[[0]][0]):
    pths = assocs[assocs.SLIT_ID == tr].CELL_LINE.tolist()
    for pth in pths:
        y = svals['POSITION_Y'][pth][pth][0] / PIXEL_INCH_RATIO
        x = svals['POSITION_X'][pth][pth][0] / PIXEL_INCH_RATIO
        cv2.circle(imc, (int(x), int(y)), 4, (0, 255, 0), -1)
#         cv2.putText(imc,"track %d: coord (%d, %d)" % (pth, int(x), int(y)), 
#                     (int(x), int(y)), cv2.FONT_HERSHEY_COMPLEX, 0.8,(255,255,255),2,cv2.LINE_AA)
cv2.imwrite(os.path.join(path, 'im_contours_%d_mask.tiff' % num), imc);

# %% [markdown]
# ### VII. Sanity Check of Recognized Pipline

# %%
## export video of valid trees

for t in invalid_trees_doubly_placed:
    slit_id = assocs[assocs.CELL_LINE == t]['SLIT_ID'].values[0]
    export_snapshot_slit(slit_id,
                         tree_assoc=assocs, 
                         slit_contours=cts, 
                         tree=tree,
                         branch=branch, 
                         tree_values=svals, 
                         tiff_path='../test/eli-new-unsync-bf-%d/out-focus/merged/merged.tif' % POSITION, 
                         out_path='../test/eli-new-unsync-bf-%d/out-focus/merged/single_analysis/invalid/doublyplaced/' % POSITION)
# Out:
# Exporting snapshot for slit 87
# Exporting snapshot for trees: [33604, 33603]
# Exporting snapshot for tree 33604...
# branch configuration for tree 33604:
# {33604: (1314350, 1314413), 1314350: (1376436, 1376391), 1376391: (1447338, 1447261)}
# parsed queue for tree 33604: [33604, 1314350, 1376436, 1376391, 1447338, 1447261, 1314413]
# Exporting snapshot for tree 33603...
# branch configuration for tree 33603:
# {33603: (724917, 724939)}
# parsed queue for tree 33603: [33603, 724917, 724939]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/doublyplaced/
# #Trees snapshot exported
# Exporting snapshot for slit 132
# Exporting snapshot for trees: [32546, 32630]
# Exporting snapshot for tree 32546...
# branch configuration for tree 32546:
# {}
# parsed queue for tree 32546: [32546]
# Exporting snapshot for tree 32630...
# branch configuration for tree 32630:
# {891794: (925948, 925949), 676613: (712075, 712146), 32630: (564488, 564445), 564488: (582126, 582210), 712075: (891827, 891794), 925948: (1007478, 1007446), 564445: (629152, 629230), 582126: (676578, 676613)}
# parsed queue for tree 32630: [32630, 564488, 582126, 676578, 676613, 712075, 891827, 891794, 925948, 1007478, 1007446, 925949, 712146, 582210, 564445, 629152, 629230]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/doublyplaced/
# #Trees snapshot exported
# Exporting snapshot for slit 63
# Exporting snapshot for trees: [33909, 33910]
# Exporting snapshot for tree 33909...
# branch configuration for tree 33909:
# {}
# parsed queue for tree 33909: [33909]
# Exporting snapshot for tree 33910...
# branch configuration for tree 33910:
# {238867: (482389, 482388), 33910: (238867, 238873)}
# parsed queue for tree 33910: [33910, 238867, 482389, 482388, 238873]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/doublyplaced/
# #Trees snapshot exported
# Exporting snapshot for slit 305
# Exporting snapshot for trees: [29093, 29139]
# Exporting snapshot for tree 29093...
# branch configuration for tree 29093:
# {}
# parsed queue for tree 29093: [29093]
# Exporting snapshot for tree 29139...
# branch configuration for tree 29139:
# {29139: (58748, 58795)}
# parsed queue for tree 29139: [29139, 58748, 58795]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/doublyplaced/
# #Trees snapshot exported
# Exporting snapshot for slit 28
# Exporting snapshot for trees: [34478, 34504]
# Exporting snapshot for tree 34478...
# branch configuration for tree 34478:
# {}
# parsed queue for tree 34478: [34478]
# Exporting snapshot for tree 34504...
# branch configuration for tree 34504:
# {34504: (274113, 274084), 536352: (571947, 571971), 274084: (536352, 536353)}
# parsed queue for tree 34504: [34504, 274113, 274084, 536352, 571947, 571971, 536353]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/doublyplaced/
# #Trees snapshot exported
# Exporting snapshot for slit 179
# Exporting snapshot for trees: [31722, 31723]
# Exporting snapshot for tree 31722...
# branch configuration for tree 31722:
# {}
# parsed queue for tree 31722: [31722]
# Exporting snapshot for tree 31723...
# branch configuration for tree 31723:
# {}
# parsed queue for tree 31723: [31723]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/doublyplaced/
# #Trees snapshot exported
# Exporting snapshot for slit 262
# Exporting snapshot for trees: [29935, 29936]
# Exporting snapshot for tree 29935...
# branch configuration for tree 29935:
# {29935: (23604, 23695)}
# parsed queue for tree 29935: [29935, 23604, 23695]
# Exporting snapshot for tree 29936...
# branch configuration for tree 29936:
# {}
# parsed queue for tree 29936: [29936]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/doublyplaced/
# #Trees snapshot exported

# %%
## export video of valid trees

for t in valid_trees:
    export_snapshot([t], 
                    tree_assoc=assocs, 
                    slit_contours=cts, 
                    tree=tree, 
                    branch=branch, 
                    tree_values=svals, 
                    tiff_path='../test/eli-new-unsync-bf-%d/out-focus/merged/merged.tif' % POSITION, 
                    out_path='../test/eli-new-unsync-bf-%d/out-focus/merged/single_analysis/valid/' % POSITION)
# Out:
# Exporting snapshot for trees: [33558]
# Exporting snapshot for tree 33558...
# branch configuration for tree 33558:
# {33558: (435026, 435064)}
# parsed queue for tree 33558: [33558, 435026, 435064]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/valid/
# #Trees snapshot exported
# Exporting snapshot for trees: [32299]
# Exporting snapshot for tree 32299...
# branch configuration for tree 32299:
# {32299: (346969, 346918)}
# parsed queue for tree 32299: [32299, 346969, 346918]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/valid/
# #Trees snapshot exported
# Exporting snapshot for trees: [31322]
# Exporting snapshot for tree 31322...
# branch configuration for tree 31322:
# {31322: (450310, 450366)}
# parsed queue for tree 31322: [31322, 450310, 450366]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/valid/
# #Trees snapshot exported
# Exporting snapshot for trees: [33414]
# Exporting snapshot for tree 33414...
# branch configuration for tree 33414:
# {33414: (399978, 400042)}
# parsed queue for tree 33414: [33414, 399978, 400042]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/valid/
# #Trees snapshot exported
# Exporting snapshot for trees: [29593]
# Exporting snapshot for tree 29593...
# branch configuration for tree 29593:
# {29593: (195338, 195339)}
# parsed queue for tree 29593: [29593, 195338, 195339]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/valid/
# #Trees snapshot exported
# Exporting snapshot for trees: [33263]
# Exporting snapshot for tree 33263...
# branch configuration for tree 33263:
# {33263: (481808, 481819)}
# parsed queue for tree 33263: [33263, 481808, 481819]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/valid/
# #Trees snapshot exported
# Exporting snapshot for trees: [29385]
# Exporting snapshot for tree 29385...
# branch configuration for tree 29385:
# {29385: (234541, 234495)}
# parsed queue for tree 29385: [29385, 234541, 234495]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/valid/
# #Trees snapshot exported
# Exporting snapshot for trees: [30079]
# Exporting snapshot for tree 30079...
# branch configuration for tree 30079:
# {30079: (531885, 531921)}
# parsed queue for tree 30079: [30079, 531885, 531921]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/valid/
# #Trees snapshot exported

# %%
## export video of valid trees

for t in invalid_trees_deathbeforetreatment:
    export_snapshot([t], 
                    tree_assoc=assocs, 
                    slit_contours=cts, 
                    tree=tree, 
                    branch=branch, 
                    tree_values=svals, 
                    tiff_path='../test/eli-new-unsync-bf-%d/out-focus/merged/merged.tif' % POSITION, 
                    out_path='../test/eli-new-unsync-bf-%d/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/' % POSITION)
# Out:
# Exporting snapshot for trees: [33655]
# Exporting snapshot for tree 33655...
# branch configuration for tree 33655:
# {33655: (511741, 511725)}
# parsed queue for tree 33655: [33655, 511741, 511725]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/
# #Trees snapshot exported
# Exporting snapshot for trees: [31892]
# Exporting snapshot for tree 31892...
# branch configuration for tree 31892:
# {31892: (317943, 317836)}
# parsed queue for tree 31892: [31892, 317943, 317836]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/
# #Trees snapshot exported
# Exporting snapshot for trees: [29108]
# Exporting snapshot for tree 29108...
# branch configuration for tree 29108:
# {29108: (472185, 472158)}
# parsed queue for tree 29108: [29108, 472185, 472158]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/
# #Trees snapshot exported
# Exporting snapshot for trees: [29303]
# Exporting snapshot for tree 29303...
# branch configuration for tree 29303:
# {29303: (138143, 138144)}
# parsed queue for tree 29303: [29303, 138143, 138144]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/
# #Trees snapshot exported

# %%
## export video of valid trees

for t in invalid_trees_nodiv:
    export_snapshot([t],
                    tree_assoc=assocs, 
                    slit_contours=cts, 
                    tree=tree, 
                    branch=branch, 
                    tree_values=svals, 
                    tiff_path='../test/eli-new-unsync-bf-%d/out-focus/merged/merged.tif' % POSITION, 
                    out_path='../test/eli-new-unsync-bf-%d/out-focus/merged/single_analysis/invalid/nodiv/' % POSITION)
# Out:
# Exporting snapshot for trees: [33451]
# Exporting snapshot for tree 33451...
# branch configuration for tree 33451:
# {}
# parsed queue for tree 33451: [33451]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [32871]
# Exporting snapshot for tree 32871...
# branch configuration for tree 32871:
# {}
# parsed queue for tree 32871: [32871]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [29471]
# Exporting snapshot for tree 29471...
# branch configuration for tree 29471:
# {}
# parsed queue for tree 29471: [29471]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [29991]
# Exporting snapshot for tree 29991...
# branch configuration for tree 29991:
# {}
# parsed queue for tree 29991: [29991]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [30779]
# Exporting snapshot for tree 30779...
# branch configuration for tree 30779:
# {}
# parsed queue for tree 30779: [30779]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [34110]
# Exporting snapshot for tree 34110...
# branch configuration for tree 34110:
# {}
# parsed queue for tree 34110: [34110]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [31557]
# Exporting snapshot for tree 31557...
# branch configuration for tree 31557:
# {}
# parsed queue for tree 31557: [31557]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [30049]
# Exporting snapshot for tree 30049...
# branch configuration for tree 30049:
# {}
# parsed queue for tree 30049: [30049]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [30564]
# Exporting snapshot for tree 30564...
# branch configuration for tree 30564:
# {}
# parsed queue for tree 30564: [30564]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [30821]
# Exporting snapshot for tree 30821...
# branch configuration for tree 30821:
# {}
# parsed queue for tree 30821: [30821]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [33641]
# Exporting snapshot for tree 33641...
# branch configuration for tree 33641:
# {}
# parsed queue for tree 33641: [33641]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [32107]
# Exporting snapshot for tree 32107...
# branch configuration for tree 32107:
# {}
# parsed queue for tree 32107: [32107]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [30076]
# Exporting snapshot for tree 30076...
# branch configuration for tree 30076:
# {}
# parsed queue for tree 30076: [30076]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [34197]
# Exporting snapshot for tree 34197...
# branch configuration for tree 34197:
# {}
# parsed queue for tree 34197: [34197]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [32389]
# Exporting snapshot for tree 32389...
# branch configuration for tree 32389:
# {}
# parsed queue for tree 32389: [32389]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [32907]
# Exporting snapshot for tree 32907...
# branch configuration for tree 32907:
# {}
# parsed queue for tree 32907: [32907]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [30865]
# Exporting snapshot for tree 30865...
# branch configuration for tree 30865:
# {}
# parsed queue for tree 30865: [30865]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [32146]
# Exporting snapshot for tree 32146...
# branch configuration for tree 32146:
# {}
# parsed queue for tree 32146: [32146]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [29845]
# Exporting snapshot for tree 29845...
# branch configuration for tree 29845:
# {}
# parsed queue for tree 29845: [29845]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [29335]
# Exporting snapshot for tree 29335...
# branch configuration for tree 29335:
# {}
# parsed queue for tree 29335: [29335]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [34200]
# Exporting snapshot for tree 34200...
# branch configuration for tree 34200:
# {}
# parsed queue for tree 34200: [34200]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [29597]
# Exporting snapshot for tree 29597...
# branch configuration for tree 29597:
# {}
# parsed queue for tree 29597: [29597]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [31384]
# Exporting snapshot for tree 31384...
# branch configuration for tree 31384:
# {}
# parsed queue for tree 31384: [31384]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [33207]
# Exporting snapshot for tree 33207...
# branch configuration for tree 33207:
# {}
# parsed queue for tree 33207: [33207]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [31684]
# Exporting snapshot for tree 31684...
# branch configuration for tree 31684:
# {}
# parsed queue for tree 31684: [31684]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [33495]
# Exporting snapshot for tree 33495...
# branch configuration for tree 33495:
# {}
# parsed queue for tree 33495: [33495]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported
# Exporting snapshot for trees: [32212]
# Exporting snapshot for tree 32212...
# branch configuration for tree 32212:
# {}
# parsed queue for tree 32212: [32212]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/nodiv/
# #Trees snapshot exported

# %%
## export video of valid trees

for t in invalid_trees_morethan1div:
    export_snapshot([t],
                    tree_assoc=assocs, 
                    slit_contours=cts, 
                    tree=tree, 
                    branch=branch, 
                    tree_values=svals, 
                    tiff_path='../test/eli-new-unsync-bf-%d/out-focus/merged/merged.tif' % POSITION, 
                    out_path='../test/eli-new-unsync-bf-%d/out-focus/merged/single_analysis/invalid/morethan1div/' % POSITION)
# Out:
# Exporting snapshot for trees: [33793]
# Exporting snapshot for tree 33793...
# branch configuration for tree 33793:
# {33793: (176508, 176502), 612627: (746190, 746175), 176502: (535651, 535614), 763573: (1105791, 1105735), 571286: (612626, 612627), 535614: (571286, 571305), 746175: (763573, 763558)}
# parsed queue for tree 33793: [33793, 176508, 176502, 535651, 535614, 571286, 612626, 612627, 746190, 746175, 763573, 1105791, 1105735, 763558, 571305]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [32772]
# Exporting snapshot for tree 32772...
# branch configuration for tree 32772:
# {79258: (440260, 440222), 32772: (79258, 79303)}
# parsed queue for tree 32772: [32772, 79258, 440260, 440222, 79303]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [33294]
# Exporting snapshot for tree 33294...
# branch configuration for tree 33294:
# {470369: (565036, 564998), 136210: (273075, 273081), 776470: (1048791, 1048846), 564998: (776470, 776497), 273081: (336395, 336394), 130618: (136210, 136201), 336395: (470369, 470358), 33294: (130618, 130592)}
# parsed queue for tree 33294: [33294, 130618, 136210, 273075, 273081, 336395, 470369, 565036, 564998, 776470, 1048791, 1048846, 776497, 470358, 336394, 136201, 130592]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [32784]
# Exporting snapshot for tree 32784...
# branch configuration for tree 32784:
# {32784: (181360, 181372), 181360: (255247, 255301), 487361: (546642, 546589), 255301: (382102, 382140), 600119: (623420, 623458), 382140: (487361, 487318), 546589: (600119, 600077)}
# parsed queue for tree 32784: [32784, 181360, 255247, 255301, 382102, 382140, 487361, 546642, 546589, 600119, 623420, 623458, 600077, 487318, 181372]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [34085]
# Exporting snapshot for tree 34085...
# branch configuration for tree 34085:
# {34085: (535879, 535926), 535879: (734443, 734521)}
# parsed queue for tree 34085: [34085, 535879, 734443, 734521, 535926]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [30857]
# Exporting snapshot for tree 30857...
# branch configuration for tree 30857:
# {30857: (111090, 111089), 111090: (190879, 190852)}
# parsed queue for tree 30857: [30857, 111090, 190879, 190852, 111089]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [29252]
# Exporting snapshot for tree 29252...
# branch configuration for tree 29252:
# {625824: (702929, 702935), 29252: (138097, 138116), 138116: (625825, 625824), 702935: (820035, 819991)}
# parsed queue for tree 29252: [29252, 138097, 138116, 625825, 625824, 702929, 702935, 820035, 819991]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [31052]
# Exporting snapshot for tree 31052...
# branch configuration for tree 31052:
# {704506: (896296, 896070), 1153091: (1212598, 1212521), 31052: (704525, 704506), 896070: (1153091, 1153200)}
# parsed queue for tree 31052: [31052, 704525, 704506, 896296, 896070, 1153091, 1212598, 1212521, 1153200]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [32526]
# Exporting snapshot for tree 32526...
# branch configuration for tree 32526:
# {516762: (676569, 676579), 676579: (1082620, 1082524), 32526: (516762, 516761)}
# parsed queue for tree 32526: [32526, 516762, 676569, 676579, 1082620, 1082524, 516761]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [30822]
# Exporting snapshot for tree 30822...
# branch configuration for tree 30822:
# {743697: (1039211, 1039181), 30822: (743697, 743661)}
# parsed queue for tree 30822: [30822, 743697, 1039211, 1039181, 743661]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [29819]
# Exporting snapshot for tree 29819...
# branch configuration for tree 29819:
# {567448: (591318, 591330), 29819: (567448, 567505), 602869: (691368, 691302), 591318: (602869, 602938), 691302: (742009, 741900)}
# parsed queue for tree 29819: [29819, 567448, 591318, 602869, 691368, 691302, 742009, 741900, 602938, 591330, 567505]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [33673]
# Exporting snapshot for tree 33673...
# branch configuration for tree 33673:
# {1230352: (1283644, 1283683), 33673: (701095, 701086), 701086: (1062913, 1062940), 1062913: (1230352, 1230320)}
# parsed queue for tree 33673: [33673, 701095, 701086, 1062913, 1230352, 1283644, 1283683, 1230320, 1062940]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [32067]
# Exporting snapshot for tree 32067...
# branch configuration for tree 32067:
# {32067: (474919, 474973), 474973: (723445, 723446), 723446: (925346, 925329)}
# parsed queue for tree 32067: [32067, 474919, 474973, 723445, 723446, 925346, 925329]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [32969]
# Exporting snapshot for tree 32969...
# branch configuration for tree 32969:
# {647376: (676951, 676952), 32969: (647376, 647431)}
# parsed queue for tree 32969: [32969, 647376, 676951, 676952, 647431]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [34251]
# Exporting snapshot for tree 34251...
# branch configuration for tree 34251:
# {357024: (784311, 784297), 784297: (870187, 870067), 34251: (356931, 357024)}
# parsed queue for tree 34251: [34251, 356931, 357024, 784311, 784297, 870187, 870067]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [30422]
# Exporting snapshot for tree 30422...
# branch configuration for tree 30422:
# {520410: (875607, 875644), 362196: (520448, 520410), 30422: (362196, 362182)}
# parsed queue for tree 30422: [30422, 362196, 520448, 520410, 875607, 875644, 362182]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [32478]
# Exporting snapshot for tree 32478...
# branch configuration for tree 32478:
# {688194: (755315, 755314), 32478: (688194, 688180)}
# parsed queue for tree 32478: [32478, 688194, 755315, 755314, 688180]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [29159]
# Exporting snapshot for tree 29159...
# branch configuration for tree 29159:
# {109584: (702886, 702847), 29159: (109620, 109584), 702847: (1017261, 1017239)}
# parsed queue for tree 29159: [29159, 109620, 109584, 702886, 702847, 1017261, 1017239]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [34029]
# Exporting snapshot for tree 34029...
# branch configuration for tree 34029:
# {34029: (547814, 547779), 547814: (913871, 913870)}
# parsed queue for tree 34029: [34029, 547814, 913871, 913870, 547779]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported
# Exporting snapshot for trees: [32127]
# Exporting snapshot for tree 32127...
# branch configuration for tree 32127:
# {32127: (364063, 364037), 364037: (593589, 593647), 593647: (646650, 646623)}
# parsed queue for tree 32127: [32127, 364063, 364037, 593589, 593647, 646650, 646623]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/morethan1div/
# #Trees snapshot exported

# %%
## export video of valid trees

for t in invalid_trees_divaftertreatment:
    export_snapshot([t],
                    tree_assoc=assocs, 
                    slit_contours=cts, 
                    tree=tree, 
                    branch=branch, 
                    tree_values=svals, 
                    tiff_path='../test/eli-new-unsync-bf-%d/out-focus/merged/merged.tif' % POSITION, 
                    out_path='../test/eli-new-unsync-bf-%d/out-focus/merged/single_analysis/invalid/divaftertreatment/' % POSITION)
# Out:
# Exporting snapshot for trees: [32020]
# Exporting snapshot for tree 32020...
# branch configuration for tree 32020:
# {32020: (761728, 761779)}
# parsed queue for tree 32020: [32020, 761728, 761779]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/divaftertreatment/
# #Trees snapshot exported
# Exporting snapshot for trees: [32353]
# Exporting snapshot for tree 32353...
# branch configuration for tree 32353:
# {32353: (823690, 823683)}
# parsed queue for tree 32353: [32353, 823690, 823683]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/divaftertreatment/
# #Trees snapshot exported

# %%
## export video of valid trees

for t in invalid_trees_deathbeforetreatment:
    export_snapshot([t],
                    tree_assoc=assocs, 
                    slit_contours=cts, 
                    tree=tree, 
                    branch=branch, 
                    tree_values=svals, 
                    tiff_path='../test/eli-new-unsync-bf-%d/out-focus/merged/merged.tif' % POSITION, 
                    out_path='../test/eli-new-unsync-bf-%d/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/' % POSITION)
# Out:
# Exporting snapshot for trees: [33655]
# Exporting snapshot for tree 33655...
# branch configuration for tree 33655:
# {33655: (511741, 511725)}
# parsed queue for tree 33655: [33655, 511741, 511725]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/
# #Trees snapshot exported
# Exporting snapshot for trees: [31892]
# Exporting snapshot for tree 31892...
# branch configuration for tree 31892:
# {31892: (317943, 317836)}
# parsed queue for tree 31892: [31892, 317943, 317836]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/
# #Trees snapshot exported
# Exporting snapshot for trees: [29108]
# Exporting snapshot for tree 29108...
# branch configuration for tree 29108:
# {29108: (472185, 472158)}
# parsed queue for tree 29108: [29108, 472185, 472158]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/
# #Trees snapshot exported
# Exporting snapshot for trees: [29303]
# Exporting snapshot for tree 29303...
# branch configuration for tree 29303:
# {29303: (138143, 138144)}
# parsed queue for tree 29303: [29303, 138143, 138144]
# writting video to dir: ../test/eli-new-unsync-bf-40/out-focus/merged/single_analysis/invalid/deathbeforetreatmen/
# #Trees snapshot exported

# %% [markdown]
# ### VIII. Death Signal Embedding and Analysis

# %%
"""
Experiment conf:
out-focus = 21 hrs (126 slides a 10 mins) + 24 hrs (144 slides a 10 mins)
caspacin = 24 hrs (48 slides a 30 mins)
first slide of caspacin refers to (126 + 1) * 600 = 76200

cell death cut-off value: 1000
"""
# Out:
# '\nExperiment conf:\nout-focus = 21 hrs (126 slides a 10 mins) + 24 hrs (144 slides a 10 mins)\ncaspacin = 24 hrs (48 slides a 30 mins)\nfirst slide of caspacin refers to (126 + 1) * 600 = 76200\n\ncell death cut-off value: 1000\n'

# %%
caspase_path = "../test/eli-new-unsync-bf-%d/caspase/" % POSITION
tiff_path = os.path.join(caspase_path, "caspasexy%dc1_sub.tif" % POSITION)
tiff_path_intersection = os.path.join(caspase_path, "caspasexy%dc1_inter.tif" % POSITION)

out_path_pics = "../results/pics/unsyn/"
if not os.path.exists(out_path_pics):
    os.makedirs(out_path_pics)

# %%
for tr in valid_trees:

    t_brightness, _ = extract_brightness(tr, tree, svals, tiff_path)
    t_time = svals['POSITION_T'][tr]

    for br in t_brightness:
        brightness = np.array(t_brightness[br])
        time = np.array(t_time[br])
        time = time[~np.isnan(brightness)]
        brightness= brightness[~np.isnan(brightness)]
        pt.plot(time, brightness, label="%d-%d" % (tr, br))
        
pt.legend(loc='best')
pt.title("Progression of cell lines' brightness measurement over time")
pt.ylabel("Sum of cell's pixels' brightness (8-bit encoding)")
pt.xlabel("Time (s)")

fr = pt.gcf()
fr.set_size_inches(10, 10)

pt.savefig(os.path.join(out_path_pics, "%d.pdf" % POSITION))

# %%
caspase_path
# Out:
# '../test/eli-new-unsync-bf-40/caspase/'

# %%
for vt in valid_trees:
    visualize_brightness_data(vt, tree, svals, tiff_path, save_vid=True, vid_path=tiff_path, out_path=caspase_path)
    pt.clf()
# Out:
# visualizing tree 33558
#   plot written to ../results/pics/unsyn/40-33558.pdf
#   video written to ../test/eli-new-unsync-bf-40/caspase/test-33558.tiff
# visualizing tree 32299
#   plot written to ../results/pics/unsyn/40-32299.pdf
#   video written to ../test/eli-new-unsync-bf-40/caspase/test-32299.tiff
# visualizing tree 31322
#   plot written to ../results/pics/unsyn/40-31322.pdf
#   video written to ../test/eli-new-unsync-bf-40/caspase/test-31322.tiff
# visualizing tree 33414
#   plot written to ../results/pics/unsyn/40-33414.pdf
#   video written to ../test/eli-new-unsync-bf-40/caspase/test-33414.tiff
# visualizing tree 29593
#   plot written to ../results/pics/unsyn/40-29593.pdf
#   video written to ../test/eli-new-unsync-bf-40/caspase/test-29593.tiff
# visualizing tree 33263
#   plot written to ../results/pics/unsyn/40-33263.pdf
#   video written to ../test/eli-new-unsync-bf-40/caspase/test-33263.tiff
# visualizing tree 29385
#   plot written to ../results/pics/unsyn/40-29385.pdf
#   video written to ../test/eli-new-unsync-bf-40/caspase/test-29385.tiff
# visualizing tree 30079
#   plot written to ../results/pics/unsyn/40-30079.pdf
#   video written to ../test/eli-new-unsync-bf-40/caspase/test-30079.tiff

# %% [markdown]
# ## IX. Embed Signal Information Into Data (OLD)

# %%
t = valid_trees[1]
t_tree, t_branch, t_brightness, svals_new = embed_cell_death_signal(t, tree, branch, svals, tiff_path)

t_time = svals_new['POSITION_T'][t]
t_x = svals_new['POSITION_X'][t]
t_y = svals_new['POSITION_Y'][t]

for br in t_brightness:
    brightness = np.array(t_brightness[br])
    time = np.array(t_time[br])
    time = time[~np.isnan(brightness)]
    brightness= brightness[~np.isnan(brightness)]
    pt.plot(time, brightness, label="%d" % br)

pt.legend()
# Out:
# processing branch 32299
# processing branch 346969
#  branch 346969 marked dead
#  shortening {tree, brightness, measurement values} of 346969 at position 181 (exclusive)
# processing branch 346918

# %%
delete_all_variables()
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? n
# Nothing done.

# %% [markdown]
# ### IX. Measurement of various slit recognition methods

# %%
pth = '../test/eli-new-unsync-bf-47/in-focus/before/bf_in-focusxy47c1c1_brightness-basic-robust-fill.tif'
imin = cv2.imread(pth)
ctrout = recognize_slits(imin)
print(len(ctrout))
# Out:
# 254

# %%
pth = '../test/eli-new-unsync-bf-47/in-focus/before/bf_in-focusxy47c1c1-mask.tif'
imin = cv2.imread(pth)
ctrout = recognize_slits(imin)
print(len(ctrout))
# Out:
# 277

# %%
pth = '../test/eli-new-unsync-bf-47/in-focus/before/test-slit-segmentation/04-fill-holes.tif'
imin = cv2.imread(pth)
ctrout = recognize_slits(imin)
print(len(ctrout))
# Out:
# 226
